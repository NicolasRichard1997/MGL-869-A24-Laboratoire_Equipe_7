# %% [markdown]
# # Data Extraction
#
# This notebook contains all the steps necessary to fetch all bugs from the Apache Hive Jira online repository (available at [this address](https://issues.apache.org/jira/projects/HIVE/issues/HIVE-25351?filter=allopenissues)). We will begin by downloading the data to this repository before filtering it.

# %% [markdown]
# ## 1. Fetching Bug Reports from Jira
#
# The first steps is to download and copy all the bug reports from *Hive 2.0.0* and subsequent versions. [On this page](https://issues.apache.org/jira/projects/HIVE/issues/HIVE-25351?filter=allopenissues), we can select `Advanced Search` and copy the following command :
# ```sql
# project = HIVE AND issuetype = Bug AND status in (Resolved, Closed) AND affectedVersion = X.Y.Z
# ```
# to fetch the bugs from a specific report. Bug reports for major and minor versions, as well as patches, can be downloaded.All of the bugs reports are kept in the `Jira_bug_data` folder, present in this repository.

# %% [markdown]
# ## 2. Removing Redundant Bugs & Concatenating the Data
# Since a given bug may affect more than a single version of the software, some redundancy is present in the downloaded data. Although, we might not want to remove duplicates as we will find the affected files for a specific bug in multiple versions of the project. So, we will use pandas data frames to load all of the data from the bugs in the files before concatenating the bugs in a single file with their specific version number.

# %%
import pandas as pd
import os
import re
from pathlib import Path

# %% [markdown]
# In order to simplify repertory changes, we'll initialize two variables, containning the paths of this current repository and the path of your clone of the Apache Hive repertory

# %%
project_repo = "/home/nicolas-richard/Desktop/.Apache_Hive_Bug_Prediction_ML_Model/"
hive_repo = "/home/nicolas-richard/Desktop/.Apache_Hive/"

# %%
project_repo = Path(project_repo)
data_dir = project_repo.joinpath("Jira_bug_data")

version_pattern = re.compile(r'_(\d+\.\d+\.\d+)_')

bug_dfs = []

for file_path in data_dir.glob("*.csv"):
    
    df = pd.read_csv(file_path)

    filename = file_path.name  # e.g., 'Hive_3.3.0_Jira_Bug_Data.csv'

    match = version_pattern.search(filename)
    version = match.group(1) if match else 'Unknown'
    
    df['Version'] = version

    df = df[['Issue key', 'Version']]
   
    bug_dfs.append(df)

concatenated_bug_dfs = pd.concat(bug_dfs, ignore_index=True)

concatenated_bug_dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2133 entries, 0 to 2132
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Issue key  2133 non-null   object
#  1   Version    2133 non-null   object
# dtypes: object(2)
# memory usage: 33.5+ KB

# %% [markdown]
# We have gathered 2133 bugs. We will run a simple check to remove duplicate lines

# %%
combined_bug_dfs = concatenated_bug_dfs.drop_duplicates()

combined_bug_dfs.info()

combined_bug_dfs.to_csv("Hive_Jira_Bug_Data.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2133 entries, 0 to 2132
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Issue key  2133 non-null   object
#  1   Version    2133 non-null   object
# dtypes: object(2)
# memory usage: 33.5+ KB

# %% [markdown]
# Despite the above lines, some duplicate bug keys will remain, which is intentional. Those bugs affected more than a single version of the software. The below line of code outputs bugs affecting multiple versions

# %%
print(concatenated_bug_dfs['Issue key'].value_counts())
# Out:
# Issue key
# HIVE-21873    6
# HIVE-21009    6
# HIVE-18284    5
# HIVE-19101    5
# HIVE-17429    5
#              ..
# HIVE-22360    1
# HIVE-22375    1
# HIVE-22514    1
# HIVE-22537    1
# HIVE-22124    1
# Name: count, Length: 1771, dtype: int64

# %% [markdown]
# ## 2. Identified Affected Java and C++ Files
#
# The goal here will be, for every single bug ID collected above, to identify the java and C++ in a given version of the software. Make sure you have a cloned repo of the Apache Hive project on you computer and the path at hand.

# %%
import os
import csv
import subprocess

# %%
os.chdir(hive_repo)
subprocess.run(['git', 'checkout', "master"], check=True)
subprocess.run(['git', 'pull'], check=True)

bug_file_map = {}

with open(project_repo.joinpath("Hive_Jira_Bug_Data.csv"), 'r') as f:
    for line in f:
        bug_id, version = line.strip().split(',')
        bug_file_map[bug_id] = {'version': version, 'files': []}

for bug_id in bug_file_map:
    version = bug_file_map[bug_id]['version']
    print(f"Searching for bug ID: {bug_id} (Version: {version})")

    try:
        result = subprocess.run(
            ["git", "log", "--grep=" + bug_id, "--name-only", "--pretty=format:"],
            capture_output=True,
            text=True,
            check=True
        )

        all_files = result.stdout.splitlines()
        filtered_files = [file for file in all_files if file.endswith(('.cpp', '.java'))]

        if filtered_files:
            bug_file_map[bug_id]['files'].extend(filtered_files)

    except subprocess.CalledProcessError as e:
        print(f"Error searching for {bug_id}: {e}")
# Out:
# Already on 'master'
# Your branch is up to date with 'origin/master'.
# Already up to date.
# Searching for bug ID: Issue key (Version: Version)
# Searching for bug ID: HIVE-25382 (Version: 2.3.2)
# Searching for bug ID: HIVE-22165 (Version: 2.1.0)
# Searching for bug ID: HIVE-21873 (Version: 2.3.4)
# Searching for bug ID: HIVE-21419 (Version: 2.3.2)
# Searching for bug ID: HIVE-21081 (Version: 2.3.3)
# Searching for bug ID: HIVE-21009 (Version: 2.1.0)
# Searching for bug ID: HIVE-20816 (Version: 2.3.2)
# Searching for bug ID: HIVE-20771 (Version: 3.1.0)
# Searching for bug ID: HIVE-20693 (Version: 2.3.2)
# Searching for bug ID: HIVE-20659 (Version: 3.1.0)
# Searching for bug ID: HIVE-20574 (Version: 2.3.2)
# Searching for bug ID: HIVE-20555 (Version: 3.1.0)
# Searching for bug ID: HIVE-20318 (Version: 3.1.0)
# Searching for bug ID: HIVE-20210 (Version: 2.3.1)
# Searching for bug ID: HIVE-20153 (Version: 2.3.2)
# Searching for bug ID: HIVE-20077 (Version: 2.3.2)
# Searching for bug ID: HIVE-20039 (Version: 2.3.2)
# Searching for bug ID: HIVE-19638 (Version: 2.3.1)
# Searching for bug ID: HIVE-19585 (Version: 2.3.2)
# Searching for bug ID: HIVE-19580 (Version: 2.3.2)
# Searching for bug ID: HIVE-19393 (Version: 2.3.2)
# Searching for bug ID: HIVE-19388 (Version: 3.1.0)
# Searching for bug ID: HIVE-19266 (Version: 2.3.2)
# Searching for bug ID: HIVE-19247 (Version: 2.2.0)
# Searching for bug ID: HIVE-19181 (Version: 2.3.2)
# Searching for bug ID: HIVE-19101 (Version: 2.3.1)
# Searching for bug ID: HIVE-19085 (Version: 2.3.2)
# Searching for bug ID: HIVE-18956 (Version: 2.3.2)
# Searching for bug ID: HIVE-18943 (Version: 2.3.2)
# Searching for bug ID: HIVE-18929 (Version: 2.3.2)
# Searching for bug ID: HIVE-18885 (Version: 2.3.2)
# Searching for bug ID: HIVE-18786 (Version: 2.3.3)
# Searching for bug ID: HIVE-18779 (Version: 2.3.2)
# Searching for bug ID: HIVE-18702 (Version: 2.3.2)
# Searching for bug ID: HIVE-18624 (Version: 2.0.0)
# Searching for bug ID: HIVE-18611 (Version: 2.3.2)
# Searching for bug ID: HIVE-18529 (Version: 2.3.2)
# Searching for bug ID: HIVE-18421 (Version: 2.2.0)
# Searching for bug ID: HIVE-18284 (Version: 3.1.2)
# Searching for bug ID: HIVE-18115 (Version: 2.3.1)
# Searching for bug ID: HIVE-17948 (Version: 2.3.2)
# Searching for bug ID: HIVE-17928 (Version: 2.3.2)
# Searching for bug ID: HIVE-17429 (Version: 2.1.0)
# Searching for bug ID: HIVE-16939 (Version: 2.3.1)
# Searching for bug ID: HIVE-16886 (Version: 2.3.3)
# Searching for bug ID: HIVE-16708 (Version: 2.3.2)
# Searching for bug ID: HIVE-28360 (Version: 3.1.3)
# Searching for bug ID: HIVE-28347 (Version: 4.0.0)
# Searching for bug ID: HIVE-28262 (Version: 3.1.3)
# Searching for bug ID: HIVE-27792 (Version: 3.1.3)
# Searching for bug ID: HIVE-27658 (Version: 3.1.3)
# Searching for bug ID: HIVE-27631 (Version: 2.3.7)
# Searching for bug ID: HIVE-27480 (Version: 3.1.3)
# Searching for bug ID: HIVE-27439 (Version: 3.1.3)
# Searching for bug ID: HIVE-27357 (Version: 3.1.3)
# Searching for bug ID: HIVE-27344 (Version: 3.1.3)
# Searching for bug ID: HIVE-27324 (Version: 3.1.3)
# Searching for bug ID: HIVE-27268 (Version: 3.1.3)
# Searching for bug ID: HIVE-26863 (Version: 3.1.3)
# Searching for bug ID: HIVE-26819 (Version: 3.1.3)
# Searching for bug ID: HIVE-26775 (Version: 3.1.3)
# Searching for bug ID: HIVE-26522 (Version: 2.3.8)
# Searching for bug ID: HIVE-26396 (Version: 3.1.3)
# Searching for bug ID: HIVE-26374 (Version: 3.1.3)
# Searching for bug ID: HIVE-26197 (Version: 4.0.0)
# Searching for bug ID: HIVE-26184 (Version: 2.3.8)
# Searching for bug ID: HIVE-24404 (Version: 2.3.7)
# Searching for bug ID: HIVE-24316 (Version: 3.1.3)
# Searching for bug ID: HIVE-21375 (Version: 3.1.3)
# Searching for bug ID: HIVE-20067 (Version: 3.1.3)
# Searching for bug ID: HIVE-20038 (Version: 4.0.0)
# Searching for bug ID: HIVE-22412 (Version: 2.0.0)
# Searching for bug ID: HIVE-22196 (Version: 3.1.2)
# Searching for bug ID: HIVE-21157 (Version: 2.0.0)
# Searching for bug ID: HIVE-21033 (Version: 2.0.0)
# Searching for bug ID: HIVE-20345 (Version: 2.0.0)
# Searching for bug ID: HIVE-18742 (Version: 2.0.0)
# Searching for bug ID: HIVE-18735 (Version: 2.0.0)
# Searching for bug ID: HIVE-18250 (Version: 2.1.0)
# Searching for bug ID: HIVE-18090 (Version: 2.0.0)
# Searching for bug ID: HIVE-17368 (Version: 2.1.0)
# Searching for bug ID: HIVE-17126 (Version: 2.0.0)
# Searching for bug ID: HIVE-16769 (Version: 2.0.0)
# Searching for bug ID: HIVE-16654 (Version: 2.0.0)
# Searching for bug ID: HIVE-16507 (Version: 2.3.0)
# Searching for bug ID: HIVE-16450 (Version: 2.0.0)
# Searching for bug ID: HIVE-16385 (Version: 2.1.0)
# Searching for bug ID: HIVE-15769 (Version: 2.1.0)
# Searching for bug ID: HIVE-15766 (Version: 2.1.1)
# Searching for bug ID: HIVE-15756 (Version: 2.0.0)
# Searching for bug ID: HIVE-15752 (Version: 2.1.0)
# Searching for bug ID: HIVE-15517 (Version: 2.1.0)
# Searching for bug ID: HIVE-15329 (Version: 2.1.0)
# Searching for bug ID: HIVE-15311 (Version: 2.1.0)
# Searching for bug ID: HIVE-15297 (Version: 2.1.0)
# Searching for bug ID: HIVE-15247 (Version: 2.1.0)
# Searching for bug ID: HIVE-15234 (Version: 2.1.0)
# Searching for bug ID: HIVE-15160 (Version: 2.1.0)
# Searching for bug ID: HIVE-15110 (Version: 2.1.0)
# Searching for bug ID: HIVE-15096 (Version: 2.1.0)
# Searching for bug ID: HIVE-15054 (Version: 2.0.0)
# Searching for bug ID: HIVE-14742 (Version: 2.0.0)
# Searching for bug ID: HIVE-14620 (Version: 2.1.0)
# Searching for bug ID: HIVE-14393 (Version: 2.1.0)
# Searching for bug ID: HIVE-14367 (Version: 2.1.0)
# Searching for bug ID: HIVE-14342 (Version: 2.0.0)
# Searching for bug ID: HIVE-14324 (Version: 2.1.0)
# Searching for bug ID: HIVE-14322 (Version: 2.1.0)
# Searching for bug ID: HIVE-14296 (Version: 2.0.0)
# Searching for bug ID: HIVE-14251 (Version: 2.0.0)
# Searching for bug ID: HIVE-14241 (Version: 2.0.0)
# Searching for bug ID: HIVE-14236 (Version: 2.1.0)
# Searching for bug ID: HIVE-14229 (Version: 2.0.0)
# Searching for bug ID: HIVE-14210 (Version: 2.1.0)
# Searching for bug ID: HIVE-14153 (Version: 2.1.0)
# Searching for bug ID: HIVE-14133 (Version: 2.1.0)
# Searching for bug ID: HIVE-14132 (Version: 2.1.0)
# Searching for bug ID: HIVE-14038 (Version: 2.0.0)
# Searching for bug ID: HIVE-14015 (Version: 2.0.0)
# Searching for bug ID: HIVE-14006 (Version: 2.0.0)
# Searching for bug ID: HIVE-13989 (Version: 2.0.0)
# Searching for bug ID: HIVE-13932 (Version: 2.0.0)
# Searching for bug ID: HIVE-13858 (Version: 2.0.0)
# Searching for bug ID: HIVE-13844 (Version: 2.0.0)
# Searching for bug ID: HIVE-13837 (Version: 2.0.0)
# Searching for bug ID: HIVE-13833 (Version: 2.1.0)
# Searching for bug ID: HIVE-13829 (Version: 2.0.0)
# Searching for bug ID: HIVE-13813 (Version: 2.0.0)
# Searching for bug ID: HIVE-13809 (Version: 2.1.0)
# Searching for bug ID: HIVE-13768 (Version: 2.0.0)
# Searching for bug ID: HIVE-13756 (Version: 2.0.0)
# Searching for bug ID: HIVE-13754 (Version: 2.0.0)
# Searching for bug ID: HIVE-13725 (Version: 2.0.0)
# Searching for bug ID: HIVE-13704 (Version: 2.0.0)
# Searching for bug ID: HIVE-13699 (Version: 2.0.0)
# Searching for bug ID: HIVE-13693 (Version: 2.1.0)
# Searching for bug ID: HIVE-13676 (Version: 2.0.0)
# Searching for bug ID: HIVE-13619 (Version: 2.1.0)
# Searching for bug ID: HIVE-13618 (Version: 2.0.0)
# Searching for bug ID: HIVE-13608 (Version: 2.0.0)
# Searching for bug ID: HIVE-13602 (Version: 2.0.0)
# Searching for bug ID: HIVE-13570 (Version: 2.0.0)
# Searching for bug ID: HIVE-13561 (Version: 2.0.0)
# Searching for bug ID: HIVE-13553 (Version: 2.0.0)
# Searching for bug ID: HIVE-13542 (Version: 2.0.0)
# Searching for bug ID: HIVE-13523 (Version: 2.0.0)
# Searching for bug ID: HIVE-13512 (Version: 2.0.0)
# Searching for bug ID: HIVE-13463 (Version: 2.0.0)
# Searching for bug ID: HIVE-13456 (Version: 2.0.0)
# Searching for bug ID: HIVE-13452 (Version: 2.1.0)
# Searching for bug ID: HIVE-13440 (Version: 2.0.0)
# Searching for bug ID: HIVE-13439 (Version: 2.0.0)
# Searching for bug ID: HIVE-13428 (Version: 2.0.0)
# Searching for bug ID: HIVE-13423 (Version: 2.0.0)
# Searching for bug ID: HIVE-13410 (Version: 2.0.0)
# Searching for bug ID: HIVE-13408 (Version: 2.0.0)
# Searching for bug ID: HIVE-13405 (Version: 2.0.0)
# Searching for bug ID: HIVE-13395 (Version: 2.0.0)
# Searching for bug ID: HIVE-13394 (Version: 2.0.0)
# Searching for bug ID: HIVE-13390 (Version: 2.0.0)
# Searching for bug ID: HIVE-13383 (Version: 2.1.0)
# Searching for bug ID: HIVE-13381 (Version: 2.0.0)
# Searching for bug ID: HIVE-13373 (Version: 2.0.0)
# Searching for bug ID: HIVE-13361 (Version: 2.1.0)
# Searching for bug ID: HIVE-13335 (Version: 2.0.0)
# Searching for bug ID: HIVE-13333 (Version: 2.0.0)
# Searching for bug ID: HIVE-13330 (Version: 2.1.0)
# Searching for bug ID: HIVE-13326 (Version: 2.0.0)
# Searching for bug ID: HIVE-13320 (Version: 2.1.0)
# Searching for bug ID: HIVE-13300 (Version: 2.0.0)
# Searching for bug ID: HIVE-13299 (Version: 2.0.0)
# Searching for bug ID: HIVE-13293 (Version: 2.0.0)
# Searching for bug ID: HIVE-13286 (Version: 2.0.0)
# Searching for bug ID: HIVE-13285 (Version: 2.1.0)
# Searching for bug ID: HIVE-13280 (Version: 2.0.0)
# Searching for bug ID: HIVE-13261 (Version: 2.0.0)
# Searching for bug ID: HIVE-13260 (Version: 2.0.0)
# Searching for bug ID: HIVE-13240 (Version: 2.0.0)
# Searching for bug ID: HIVE-13236 (Version: 2.0.0)
# Searching for bug ID: HIVE-13235 (Version: 2.0.0)
# Searching for bug ID: HIVE-13225 (Version: 2.1.0)
# Searching for bug ID: HIVE-13217 (Version: 2.0.0)
# Searching for bug ID: HIVE-13216 (Version: 2.0.0)
# Searching for bug ID: HIVE-13201 (Version: 2.0.0)
# Searching for bug ID: HIVE-13200 (Version: 2.0.0)
# Searching for bug ID: HIVE-13191 (Version: 2.1.0)
# Searching for bug ID: HIVE-13186 (Version: 2.0.0)
# Searching for bug ID: HIVE-13175 (Version: 2.0.0)
# Searching for bug ID: HIVE-13174 (Version: 2.0.0)
# Searching for bug ID: HIVE-13169 (Version: 2.0.0)
# Searching for bug ID: HIVE-13163 (Version: 2.1.0)
# Searching for bug ID: HIVE-13159 (Version: 2.0.0)
# Searching for bug ID: HIVE-13151 (Version: 2.0.0)
# Searching for bug ID: HIVE-13144 (Version: 2.0.0)
# Searching for bug ID: HIVE-13141 (Version: 2.0.0)
# Searching for bug ID: HIVE-13134 (Version: 2.1.0)
# Searching for bug ID: HIVE-13126 (Version: 2.0.0)
# Searching for bug ID: HIVE-13108 (Version: 2.0.1)
# Searching for bug ID: HIVE-13105 (Version: 2.0.0)
# Searching for bug ID: HIVE-13101 (Version: 2.0.0)
# Searching for bug ID: HIVE-13096 (Version: 2.1.0)
# Searching for bug ID: HIVE-13094 (Version: 2.1.0)
# Searching for bug ID: HIVE-13083 (Version: 2.1.0)
# Searching for bug ID: HIVE-13082 (Version: 2.0.0)
# Searching for bug ID: HIVE-13071 (Version: 2.0.0)
# Searching for bug ID: HIVE-13065 (Version: 2.0.0)
# Searching for bug ID: HIVE-13062 (Version: 2.1.0)
# Searching for bug ID: HIVE-13042 (Version: 2.1.0)
# Searching for bug ID: HIVE-13039 (Version: 2.0.0)
# Searching for bug ID: HIVE-13036 (Version: 2.1.0)
# Searching for bug ID: HIVE-13032 (Version: 2.1.0)
# Searching for bug ID: HIVE-13024 (Version: 2.0.0)
# Searching for bug ID: HIVE-13023 (Version: 2.0.0)
# Searching for bug ID: HIVE-12999 (Version: 2.1.0)
# Searching for bug ID: HIVE-12996 (Version: 2.0.0)
# Searching for bug ID: HIVE-12993 (Version: 2.1.0)
# Searching for bug ID: HIVE-12992 (Version: 2.0.0)
# Searching for bug ID: HIVE-12981 (Version: 2.0.0)
# Searching for bug ID: HIVE-12964 (Version: 2.1.0)
# Searching for bug ID: HIVE-12947 (Version: 2.0.0)
# Searching for bug ID: HIVE-12945 (Version: 2.0.0)
# Searching for bug ID: HIVE-12937 (Version: 2.1.0)
# Searching for bug ID: HIVE-12933 (Version: 2.1.0)
# Searching for bug ID: HIVE-12931 (Version: 2.0.0)
# Searching for bug ID: HIVE-12927 (Version: 2.0.0)
# Searching for bug ID: HIVE-12926 (Version: 2.0.0)
# Searching for bug ID: HIVE-12911 (Version: 2.1.0)
# Searching for bug ID: HIVE-12909 (Version: 2.0.0)
# Searching for bug ID: HIVE-12905 (Version: 2.0.0)
# Searching for bug ID: HIVE-12904 (Version: 2.0.0)
# Searching for bug ID: HIVE-12896 (Version: 2.0.0)
# Searching for bug ID: HIVE-12893 (Version: 2.0.0)
# Searching for bug ID: HIVE-12879 (Version: 2.1.0)
# Searching for bug ID: HIVE-12864 (Version: 2.1.0)
# Searching for bug ID: HIVE-12826 (Version: 2.1.0)
# Searching for bug ID: HIVE-12824 (Version: 2.0.0)
# Searching for bug ID: HIVE-12820 (Version: 2.1.0)
# Searching for bug ID: HIVE-12815 (Version: 2.0.0)
# Searching for bug ID: HIVE-12809 (Version: 2.1.0)
# Searching for bug ID: HIVE-12808 (Version: 2.0.0)
# Searching for bug ID: HIVE-12800 (Version: 2.1.0)
# Searching for bug ID: HIVE-12797 (Version: 2.0.0)
# Searching for bug ID: HIVE-12786 (Version: 2.0.0)
# Searching for bug ID: HIVE-12784 (Version: 2.0.0)
# Searching for bug ID: HIVE-12768 (Version: 2.0.0)
# Searching for bug ID: HIVE-12767 (Version: 2.0.0)
# Searching for bug ID: HIVE-12766 (Version: 2.0.0)
# Searching for bug ID: HIVE-12762 (Version: 2.1.0)
# Searching for bug ID: HIVE-12758 (Version: 2.1.0)
# Searching for bug ID: HIVE-12743 (Version: 2.1.0)
# Searching for bug ID: HIVE-12741 (Version: 2.1.0)
# Searching for bug ID: HIVE-12740 (Version: 2.0.0)
# Searching for bug ID: HIVE-12735 (Version: 2.1.0)
# Searching for bug ID: HIVE-12734 (Version: 2.2.0)
# Searching for bug ID: HIVE-12728 (Version: 2.1.0)
# Searching for bug ID: HIVE-12726 (Version: 2.0.0)
# Searching for bug ID: HIVE-12725 (Version: 2.0.0)
# Searching for bug ID: HIVE-12724 (Version: 2.0.0)
# Searching for bug ID: HIVE-12712 (Version: 2.1.0)
# Searching for bug ID: HIVE-12708 (Version: 2.0.0)
# Searching for bug ID: HIVE-12698 (Version: 2.0.0)
# Searching for bug ID: HIVE-12694 (Version: 2.1.0)
# Searching for bug ID: HIVE-12688 (Version: 2.0.0)
# Searching for bug ID: HIVE-12687 (Version: 2.1.0)
# Searching for bug ID: HIVE-12685 (Version: 2.1.0)
# Searching for bug ID: HIVE-12684 (Version: 2.1.0)
# Searching for bug ID: HIVE-12662 (Version: 2.1.0)
# Searching for bug ID: HIVE-12657 (Version: 2.0.0)
# Searching for bug ID: HIVE-12643 (Version: 2.0.0)
# Searching for bug ID: HIVE-12639 (Version: 2.1.0)
# Searching for bug ID: HIVE-12633 (Version: 2.1.0)
# Searching for bug ID: HIVE-12609 (Version: 2.1.0)
# Searching for bug ID: HIVE-12603 (Version: 2.0.0)
# Searching for bug ID: HIVE-12601 (Version: 2.0.0)
# Searching for bug ID: HIVE-12599 (Version: 2.0.0)
# Searching for bug ID: HIVE-12596 (Version: 2.0.0)
# Searching for bug ID: HIVE-12590 (Version: 2.0.0)
# Searching for bug ID: HIVE-12584 (Version: 2.1.0)
# Searching for bug ID: HIVE-12578 (Version: 2.0.0)
# Searching for bug ID: HIVE-12577 (Version: 2.0.0)
# Searching for bug ID: HIVE-12572 (Version: 2.0.0)
# Searching for bug ID: HIVE-12569 (Version: 2.0.0)
# Searching for bug ID: HIVE-12542 (Version: 2.0.0)
# Searching for bug ID: HIVE-12537 (Version: 2.0.0)
# Searching for bug ID: HIVE-12532 (Version: 2.0.0)
# Searching for bug ID: HIVE-12510 (Version: 2.0.0)
# Searching for bug ID: HIVE-12509 (Version: 2.0.0)
# Searching for bug ID: HIVE-12508 (Version: 2.0.0)
# Searching for bug ID: HIVE-12503 (Version: 2.0.0)
# Searching for bug ID: HIVE-12500 (Version: 2.0.0)
# Searching for bug ID: HIVE-12498 (Version: 2.0.0)
# Searching for bug ID: HIVE-12491 (Version: 2.0.0)
# Searching for bug ID: HIVE-12490 (Version: 2.0.0)
# Searching for bug ID: HIVE-12487 (Version: 2.0.0)
# Searching for bug ID: HIVE-12479 (Version: 2.0.0)
# Searching for bug ID: HIVE-12478 (Version: 2.1.0)
# Searching for bug ID: HIVE-12477 (Version: 2.0.0)
# Searching for bug ID: HIVE-12473 (Version: 2.0.0)
# Searching for bug ID: HIVE-12472 (Version: 2.0.0)
# Searching for bug ID: HIVE-12465 (Version: 2.0.0)
# Searching for bug ID: HIVE-12463 (Version: 2.0.0)
# Searching for bug ID: HIVE-12462 (Version: 2.0.0)
# Searching for bug ID: HIVE-12456 (Version: 2.0.0)
# Searching for bug ID: HIVE-12453 (Version: 2.0.0)
# Searching for bug ID: HIVE-12452 (Version: 2.0.0)
# Searching for bug ID: HIVE-12451 (Version: 2.0.0)
# Searching for bug ID: HIVE-12450 (Version: 2.0.0)
# Searching for bug ID: HIVE-12445 (Version: 2.0.0)
# Searching for bug ID: HIVE-12435 (Version: 2.0.0)
# Searching for bug ID: HIVE-12407 (Version: 2.0.0)
# Searching for bug ID: HIVE-12405 (Version: 2.0.0)
# Searching for bug ID: HIVE-12404 (Version: 2.0.0)
# Searching for bug ID: HIVE-12399 (Version: 2.0.0)
# Searching for bug ID: HIVE-12396 (Version: 2.0.0)
# Searching for bug ID: HIVE-12394 (Version: 2.0.0)
# Searching for bug ID: HIVE-12393 (Version: 2.0.0)
# Searching for bug ID: HIVE-12391 (Version: 2.0.0)
# Searching for bug ID: HIVE-12385 (Version: 2.0.0)
# Searching for bug ID: HIVE-12378 (Version: 2.0.0)
# Searching for bug ID: HIVE-12364 (Version: 2.0.0)
# Searching for bug ID: HIVE-12363 (Version: 2.0.0)
# Searching for bug ID: HIVE-12349 (Version: 2.0.0)
# Searching for bug ID: HIVE-12344 (Version: 2.0.0)
# Searching for bug ID: HIVE-12332 (Version: 2.0.0)
# Searching for bug ID: HIVE-12330 (Version: 2.0.0)
# Searching for bug ID: HIVE-12315 (Version: 2.0.0)
# Searching for bug ID: HIVE-12304 (Version: 2.0.0)
# Searching for bug ID: HIVE-12302 (Version: 2.0.0)
# Searching for bug ID: HIVE-12281 (Version: 2.0.0)
# Searching for bug ID: HIVE-12264 (Version: 2.0.0)
# Searching for bug ID: HIVE-12261 (Version: 2.0.0)
# Searching for bug ID: HIVE-12260 (Version: 2.0.0)
# Searching for bug ID: HIVE-12257 (Version: 2.0.0)
# Searching for bug ID: HIVE-12246 (Version: 2.0.0)
# Searching for bug ID: HIVE-12238 (Version: 2.0.0)
# Searching for bug ID: HIVE-12234 (Version: 2.0.0)
# Searching for bug ID: HIVE-12223 (Version: 2.0.0)
# Searching for bug ID: HIVE-12215 (Version: 2.0.0)
# Searching for bug ID: HIVE-12210 (Version: 2.0.0)
# Searching for bug ID: HIVE-12208 (Version: 2.0.0)
# Searching for bug ID: HIVE-12207 (Version: 2.0.0)
# Searching for bug ID: HIVE-12204 (Version: 2.0.0)
# Searching for bug ID: HIVE-12198 (Version: 2.0.0)
# Searching for bug ID: HIVE-12189 (Version: 2.0.0)
# Searching for bug ID: HIVE-12171 (Version: 2.0.0)
# Searching for bug ID: HIVE-12166 (Version: 2.0.0)
# Searching for bug ID: HIVE-12090 (Version: 2.0.0)
# Searching for bug ID: HIVE-12068 (Version: 2.0.0)
# Searching for bug ID: HIVE-12058 (Version: 2.0.0)
# Searching for bug ID: HIVE-12039 (Version: 2.0.0)
# Searching for bug ID: HIVE-12021 (Version: 2.0.0)
# Searching for bug ID: HIVE-12008 (Version: 2.0.0)
# Searching for bug ID: HIVE-11980 (Version: 2.0.0)
# Searching for bug ID: HIVE-11975 (Version: 2.0.0)
# Searching for bug ID: HIVE-11966 (Version: 2.0.0)
# Searching for bug ID: HIVE-11954 (Version: 2.0.0)
# Searching for bug ID: HIVE-11945 (Version: 2.0.0)
# Searching for bug ID: HIVE-11932 (Version: 2.0.0)
# Searching for bug ID: HIVE-11928 (Version: 2.0.0)
# Searching for bug ID: HIVE-11922 (Version: 2.0.0)
# Searching for bug ID: HIVE-11889 (Version: 2.0.0)
# Searching for bug ID: HIVE-11875 (Version: 2.0.0)
# Searching for bug ID: HIVE-11863 (Version: 2.0.0)
# Searching for bug ID: HIVE-11860 (Version: 2.0.0)
# Searching for bug ID: HIVE-11847 (Version: 2.0.0)
# Searching for bug ID: HIVE-11843 (Version: 2.0.0)
# Searching for bug ID: HIVE-11842 (Version: 2.0.0)
# Searching for bug ID: HIVE-11841 (Version: 2.0.0)
# Searching for bug ID: HIVE-11838 (Version: 2.0.0)
# Searching for bug ID: HIVE-11835 (Version: 2.0.0)
# Searching for bug ID: HIVE-11832 (Version: 2.0.0)
# Searching for bug ID: HIVE-11826 (Version: 2.0.0)
# Searching for bug ID: HIVE-11824 (Version: 2.0.0)
# Searching for bug ID: HIVE-11821 (Version: 2.0.0)
# Searching for bug ID: HIVE-11820 (Version: 2.0.0)
# Searching for bug ID: HIVE-11813 (Version: 2.0.0)
# Searching for bug ID: HIVE-11801 (Version: 2.0.0)
# Searching for bug ID: HIVE-11795 (Version: 2.0.0)
# Searching for bug ID: HIVE-11792 (Version: 2.0.0)
# Searching for bug ID: HIVE-11781 (Version: 2.0.0)
# Searching for bug ID: HIVE-11761 (Version: 2.0.0)
# Searching for bug ID: HIVE-11751 (Version: 2.0.0)
# Searching for bug ID: HIVE-11745 (Version: 2.0.0)
# Searching for bug ID: HIVE-11726 (Version: 2.0.0)
# Searching for bug ID: HIVE-11723 (Version: 2.0.0)
# Searching for bug ID: HIVE-11721 (Version: 2.0.0)
# Searching for bug ID: HIVE-11710 (Version: 2.0.0)
# Searching for bug ID: HIVE-11705 (Version: 2.0.0)
# Searching for bug ID: HIVE-11698 (Version: 2.0.0)
# Searching for bug ID: HIVE-11696 (Version: 2.0.0)
# Searching for bug ID: HIVE-11669 (Version: 2.0.0)
# Searching for bug ID: HIVE-11658 (Version: 2.0.0)
# Searching for bug ID: HIVE-11652 (Version: 2.0.0)
# Searching for bug ID: HIVE-11604 (Version: 2.0.0)
# Searching for bug ID: HIVE-11602 (Version: 2.0.0)
# Searching for bug ID: HIVE-11596 (Version: 2.0.0)
# Searching for bug ID: HIVE-11594 (Version: 2.0.0)
# Searching for bug ID: HIVE-11592 (Version: 2.0.0)
# Searching for bug ID: HIVE-11590 (Version: 2.0.0)
# Searching for bug ID: HIVE-11581 (Version: 2.0.0)
# Searching for bug ID: HIVE-11578 (Version: 2.0.0)
# Searching for bug ID: HIVE-11573 (Version: 2.0.0)
# Searching for bug ID: HIVE-11556 (Version: 2.0.0)
# Searching for bug ID: HIVE-11546 (Version: 2.0.0)
# Searching for bug ID: HIVE-11541 (Version: 2.0.0)
# Searching for bug ID: HIVE-11511 (Version: 2.0.0)
# Searching for bug ID: HIVE-11498 (Version: 2.0.0)
# Searching for bug ID: HIVE-11497 (Version: 2.0.0)
# Searching for bug ID: HIVE-11493 (Version: 2.0.0)
# Searching for bug ID: HIVE-11476 (Version: 2.0.0)
# Searching for bug ID: HIVE-11472 (Version: 2.0.0)
# Searching for bug ID: HIVE-11468 (Version: 2.0.0)
# Searching for bug ID: HIVE-11462 (Version: 2.0.0)
# Searching for bug ID: HIVE-11452 (Version: 2.0.0)
# Searching for bug ID: HIVE-11451 (Version: 2.0.0)
# Searching for bug ID: HIVE-11446 (Version: 2.0.0)
# Searching for bug ID: HIVE-11434 (Version: 2.0.0)
# Searching for bug ID: HIVE-11433 (Version: 2.0.0)
# Searching for bug ID: HIVE-11430 (Version: 2.0.0)
# Searching for bug ID: HIVE-11428 (Version: 2.0.0)
# Searching for bug ID: HIVE-11425 (Version: 2.0.0)
# Searching for bug ID: HIVE-11423 (Version: 2.0.0)
# Searching for bug ID: HIVE-11413 (Version: 2.0.0)
# Searching for bug ID: HIVE-11406 (Version: 2.0.0)
# Searching for bug ID: HIVE-11397 (Version: 2.0.0)
# Searching for bug ID: HIVE-11375 (Version: 2.0.0)
# Searching for bug ID: HIVE-11332 (Version: 2.0.0)
# Searching for bug ID: HIVE-11312 (Version: 2.0.0)
# Searching for bug ID: HIVE-11303 (Version: 2.0.0)
# Searching for bug ID: HIVE-11293 (Version: 2.0.0)
# Searching for bug ID: HIVE-11284 (Version: 2.0.0)
# Searching for bug ID: HIVE-11258 (Version: 2.0.0)
# Searching for bug ID: HIVE-11255 (Version: 2.0.0)
# Searching for bug ID: HIVE-11237 (Version: 2.0.0)
# Searching for bug ID: HIVE-11230 (Version: 2.0.0)
# Searching for bug ID: HIVE-11229 (Version: 2.0.0)
# Searching for bug ID: HIVE-11228 (Version: 2.0.0)
# Searching for bug ID: HIVE-11221 (Version: 2.0.0)
# Searching for bug ID: HIVE-11215 (Version: 2.0.0)
# Searching for bug ID: HIVE-11202 (Version: 2.0.0)
# Searching for bug ID: HIVE-11198 (Version: 2.0.0)
# Searching for bug ID: HIVE-11194 (Version: 2.0.0)
# Searching for bug ID: HIVE-11165 (Version: 2.0.0)
# Searching for bug ID: HIVE-11157 (Version: 2.0.0)
# Searching for bug ID: HIVE-11135 (Version: 2.0.0)
# Searching for bug ID: HIVE-11122 (Version: 2.0.0)
# Searching for bug ID: HIVE-11120 (Version: 2.0.0)
# Searching for bug ID: HIVE-11118 (Version: 2.0.0)
# Searching for bug ID: HIVE-11102 (Version: 2.0.0)
# Searching for bug ID: HIVE-11058 (Version: 2.0.0)
# Searching for bug ID: HIVE-11051 (Version: 2.0.0)
# Searching for bug ID: HIVE-11043 (Version: 2.0.0)
# Searching for bug ID: HIVE-11038 (Version: 2.0.0)
# Searching for bug ID: HIVE-11035 (Version: 2.0.0)
# Searching for bug ID: HIVE-11031 (Version: 2.0.0)
# Searching for bug ID: HIVE-11023 (Version: 2.0.0)
# Searching for bug ID: HIVE-11021 (Version: 2.0.0)
# Searching for bug ID: HIVE-10996 (Version: 2.0.0)
# Searching for bug ID: HIVE-10974 (Version: 2.0.0)
# Searching for bug ID: HIVE-10972 (Version: 2.0.0)
# Searching for bug ID: HIVE-10707 (Version: 2.0.0)
# Searching for bug ID: HIVE-10651 (Version: 2.0.0)
# Searching for bug ID: HIVE-10233 (Version: 2.0.0)
# Searching for bug ID: HIVE-10021 (Version: 2.0.0)
# Searching for bug ID: HIVE-9499 (Version: 2.0.0)
# Searching for bug ID: HIVE-7428 (Version: 2.0.0)
# Searching for bug ID: HIVE-4413 (Version: 2.0.0)
# Searching for bug ID: HIVE-4243 (Version: 2.0.0)
# Searching for bug ID: HIVE-1863 (Version: 2.0.0)
# Searching for bug ID: HIVE-28515 (Version: 4.0.0)
# Searching for bug ID: HIVE-28487 (Version: 4.0.0)
# Searching for bug ID: HIVE-28451 (Version: 4.0.0)
# Searching for bug ID: HIVE-28439 (Version: 4.0.0)
# Searching for bug ID: HIVE-28426 (Version: 4.0.0)
# Searching for bug ID: HIVE-28366 (Version: 4.0.0)
# Searching for bug ID: HIVE-28353 (Version: 4.0.0)
# Searching for bug ID: HIVE-28330 (Version: 4.0.0)
# Searching for bug ID: HIVE-28285 (Version: 4.0.0)
# Searching for bug ID: HIVE-28278 (Version: 4.0.0)
# Searching for bug ID: HIVE-28277 (Version: 4.0.0)
# Searching for bug ID: HIVE-28266 (Version: 4.0.0)
# Searching for bug ID: HIVE-28264 (Version: 4.0.0)
# Searching for bug ID: HIVE-28239 (Version: 4.0.0)
# Searching for bug ID: HIVE-28207 (Version: 4.0.0)
# Searching for bug ID: HIVE-28202 (Version: 4.0.0)
# Searching for bug ID: HIVE-28190 (Version: 4.0.0)
# Searching for bug ID: HIVE-28173 (Version: 4.0.0)
# Searching for bug ID: HIVE-28166 (Version: 4.0.0)
# Searching for bug ID: HIVE-28143 (Version: 4.0.0)
# Searching for bug ID: HIVE-28123 (Version: 4.0.0)
# Searching for bug ID: HIVE-28121 (Version: 4.0.0)
# Searching for bug ID: HIVE-28009 (Version: 4.0.0)
# Searching for bug ID: HIVE-28006 (Version: 4.0.0)
# Searching for bug ID: HIVE-27801 (Version: 4.0.0)
# Searching for bug ID: HIVE-27649 (Version: 3.1.2)
# Searching for bug ID: HIVE-27071 (Version: 4.0.0)
# Searching for bug ID: HIVE-27063 (Version: 4.0.0)
# Searching for bug ID: HIVE-26911 (Version: 4.0.0)
# Searching for bug ID: HIVE-26778 (Version: 4.0.0)
# Searching for bug ID: HIVE-26767 (Version: 4.0.0)
# Searching for bug ID: HIVE-26508 (Version: 4.0.0)
# Searching for bug ID: HIVE-26415 (Version: 4.0.0)
# Searching for bug ID: HIVE-26339 (Version: 4.0.0)
# Searching for bug ID: HIVE-26268 (Version: 4.0.0)
# Searching for bug ID: HIVE-26158 (Version: 4.0.0)
# Searching for bug ID: HIVE-26036 (Version: 3.1.2)
# Searching for bug ID: HIVE-26018 (Version: 3.1.0)
# Searching for bug ID: HIVE-26017 (Version: 4.0.0)
# Searching for bug ID: HIVE-25986 (Version: 4.0.0)
# Searching for bug ID: HIVE-25978 (Version: 4.0.0)
# Searching for bug ID: HIVE-25973 (Version: 4.0.0)
# Searching for bug ID: HIVE-25964 (Version: 4.0.0)
# Searching for bug ID: HIVE-25957 (Version: 4.0.0)
# Searching for bug ID: HIVE-25926 (Version: 4.0.0)
# Searching for bug ID: HIVE-25917 (Version: 4.0.0)
# Searching for bug ID: HIVE-25914 (Version: 4.0.0)
# Searching for bug ID: HIVE-25912 (Version: 3.1.2)
# Searching for bug ID: HIVE-25907 (Version: 4.0.0)
# Searching for bug ID: HIVE-25905 (Version: 4.0.0)
# Searching for bug ID: HIVE-25853 (Version: 4.0.0)
# Searching for bug ID: HIVE-25825 (Version: 4.0.0)
# Searching for bug ID: HIVE-25811 (Version: 4.0.0)
# Searching for bug ID: HIVE-25803 (Version: 4.0.0)
# Searching for bug ID: HIVE-25802 (Version: 4.0.0)
# Searching for bug ID: HIVE-25795 (Version: 3.1.2)
# Searching for bug ID: HIVE-25777 (Version: 3.1.2)
# Searching for bug ID: HIVE-25774 (Version: 4.0.0)
# Searching for bug ID: HIVE-25766 (Version: 4.0.0)
# Searching for bug ID: HIVE-25758 (Version: 4.0.0)
# Searching for bug ID: HIVE-25757 (Version: 4.0.0)
# Searching for bug ID: HIVE-25749 (Version: 4.0.0)
# Searching for bug ID: HIVE-25746 (Version: 4.0.0)
# Searching for bug ID: HIVE-25734 (Version: 4.0.0)
# Searching for bug ID: HIVE-25716 (Version: 4.0.0)
# Searching for bug ID: HIVE-25675 (Version: 4.0.0)
# Searching for bug ID: HIVE-25659 (Version: 3.1.0)
# Searching for bug ID: HIVE-25646 (Version: 3.1.2)
# Searching for bug ID: HIVE-25626 (Version: 3.1.2)
# Searching for bug ID: HIVE-25621 (Version: 4.0.0)
# Searching for bug ID: HIVE-25605 (Version: 4.0.0)
# Searching for bug ID: HIVE-25582 (Version: 4.0.0)
# Searching for bug ID: HIVE-25577 (Version: 3.1.2)
# Searching for bug ID: HIVE-25570 (Version: 4.0.0)
# Searching for bug ID: HIVE-25547 (Version: 4.0.0)
# Searching for bug ID: HIVE-25538 (Version: 4.0.0)
# Searching for bug ID: HIVE-25530 (Version: 4.0.0)
# Searching for bug ID: HIVE-25408 (Version: 4.0.0)
# Searching for bug ID: HIVE-25386 (Version: 4.0.0)
# Searching for bug ID: HIVE-25384 (Version: 4.0.0)
# Searching for bug ID: HIVE-25316 (Version: 4.0.0)
# Searching for bug ID: HIVE-25299 (Version: 3.1.2)
# Searching for bug ID: HIVE-25268 (Version: 3.1.2)
# Searching for bug ID: HIVE-25242 (Version: 4.0.0)
# Searching for bug ID: HIVE-25188 (Version: 4.0.0)
# Searching for bug ID: HIVE-25163 (Version: 4.0.0)
# Searching for bug ID: HIVE-25150 (Version: 4.0.0)
# Searching for bug ID: HIVE-25117 (Version: 4.0.0)
# Searching for bug ID: HIVE-25009 (Version: 4.0.0)
# Searching for bug ID: HIVE-24957 (Version: 4.0.0)
# Searching for bug ID: HIVE-24951 (Version: 4.0.0)
# Searching for bug ID: HIVE-24944 (Version: 3.1.0)
# Searching for bug ID: HIVE-24928 (Version: 4.0.0)
# Searching for bug ID: HIVE-24902 (Version: 3.1.2)
# Searching for bug ID: HIVE-24898 (Version: 4.0.0)
# Searching for bug ID: HIVE-24882 (Version: 4.0.0)
# Searching for bug ID: HIVE-24876 (Version: 4.0.0)
# Searching for bug ID: HIVE-24851 (Version: 3.1.2)
# Searching for bug ID: HIVE-24849 (Version: 2.3.4)
# Searching for bug ID: HIVE-24809 (Version: 4.0.0)
# Searching for bug ID: HIVE-24803 (Version: 4.0.0)
# Searching for bug ID: HIVE-24786 (Version: 4.0.0)
# Searching for bug ID: HIVE-24751 (Version: 4.0.0)
# Searching for bug ID: HIVE-24691 (Version: 4.0.0)
# Searching for bug ID: HIVE-24606 (Version: 3.1.2)
# Searching for bug ID: HIVE-24579 (Version: 3.1.2)
# Searching for bug ID: HIVE-24570 (Version: 3.1.0)
# Searching for bug ID: HIVE-24550 (Version: 4.0.0)
# Searching for bug ID: HIVE-24530 (Version: 4.0.0)
# Searching for bug ID: HIVE-24523 (Version: 4.0.0)
# Searching for bug ID: HIVE-24514 (Version: 4.0.0)
# Searching for bug ID: HIVE-24501 (Version: 4.0.0)
# Searching for bug ID: HIVE-24446 (Version: 4.0.0)
# Searching for bug ID: HIVE-24345 (Version: 4.0.0)
# Searching for bug ID: HIVE-24322 (Version: 4.0.0)
# Searching for bug ID: HIVE-24293 (Version: 4.0.0)
# Searching for bug ID: HIVE-24256 (Version: 4.0.0)
# Searching for bug ID: HIVE-24213 (Version: 4.0.0)
# Searching for bug ID: HIVE-24198 (Version: 4.0.0)
# Searching for bug ID: HIVE-24165 (Version: 4.0.0)
# Searching for bug ID: HIVE-24147 (Version: 4.0.0)
# Searching for bug ID: HIVE-24097 (Version: 4.0.0)
# Searching for bug ID: HIVE-24070 (Version: 4.0.0)
# Searching for bug ID: HIVE-24068 (Version: 4.0.0)
# Searching for bug ID: HIVE-24030 (Version: 4.0.0)
# Searching for bug ID: HIVE-24020 (Version: 3.1.2)
# Searching for bug ID: HIVE-23968 (Version: 4.0.0)
# Searching for bug ID: HIVE-23962 (Version: 4.0.0)
# Searching for bug ID: HIVE-23925 (Version: 4.0.0)
# Searching for bug ID: HIVE-23887 (Version: 4.0.0)
# Searching for bug ID: HIVE-23851 (Version: 4.0.0)
# Searching for bug ID: HIVE-23763 (Version: 4.0.0)
# Searching for bug ID: HIVE-23752 (Version: 4.0.0)
# Searching for bug ID: HIVE-23582 (Version: 4.0.0)
# Searching for bug ID: HIVE-23580 (Version: 4.0.0)
# Searching for bug ID: HIVE-23442 (Version: 4.0.0)
# Searching for bug ID: HIVE-23423 (Version: 4.0.0)
# Searching for bug ID: HIVE-23408 (Version: 4.0.0)
# Searching for bug ID: HIVE-23358 (Version: 4.0.0)
# Searching for bug ID: HIVE-23345 (Version: 4.0.0)
# Searching for bug ID: HIVE-23339 (Version: 3.1.0)
# Searching for bug ID: HIVE-22988 (Version: 4.0.0)
# Searching for bug ID: HIVE-22982 (Version: 4.0.0)
# Searching for bug ID: HIVE-22961 (Version: 4.0.0)
# Searching for bug ID: HIVE-22955 (Version: 4.0.0)
# Searching for bug ID: HIVE-22951 (Version: 4.0.0)
# Searching for bug ID: HIVE-22950 (Version: 4.0.0)
# Searching for bug ID: HIVE-22948 (Version: 3.1.2)
# Searching for bug ID: HIVE-22903 (Version: 4.0.0)
# Searching for bug ID: HIVE-22898 (Version: 4.0.0)
# Searching for bug ID: HIVE-22880 (Version: 4.0.0)
# Searching for bug ID: HIVE-22877 (Version: 4.0.0)
# Searching for bug ID: HIVE-22853 (Version: 4.0.0)
# Searching for bug ID: HIVE-22826 (Version: 4.0.0)
# Searching for bug ID: HIVE-22824 (Version: 4.0.0)
# Searching for bug ID: HIVE-22739 (Version: 4.0.0)
# Searching for bug ID: HIVE-22708 (Version: 4.0.0)
# Searching for bug ID: HIVE-22663 (Version: 4.0.0)
# Searching for bug ID: HIVE-22636 (Version: 4.0.0)
# Searching for bug ID: HIVE-22633 (Version: 3.1.0)
# Searching for bug ID: HIVE-22555 (Version: 4.0.0)
# Searching for bug ID: HIVE-22546 (Version: 4.0.0)
# Searching for bug ID: HIVE-22544 (Version: 4.0.0)
# Searching for bug ID: HIVE-22537 (Version: 4.0.0)
# Searching for bug ID: HIVE-22514 (Version: 4.0.0)
# Searching for bug ID: HIVE-22407 (Version: 3.1.2)
# Searching for bug ID: HIVE-22375 (Version: 4.0.0)
# Searching for bug ID: HIVE-22368 (Version: 3.1.0)
# Searching for bug ID: HIVE-22360 (Version: 4.0.0)
# Searching for bug ID: HIVE-22351 (Version: 4.0.0)
# Searching for bug ID: HIVE-22336 (Version: 4.0.0)
# Searching for bug ID: HIVE-22317 (Version: 4.0.0)
# Searching for bug ID: HIVE-22313 (Version: 4.0.0)
# Searching for bug ID: HIVE-22290 (Version: 4.0.0)
# Searching for bug ID: HIVE-22227 (Version: 4.0.0)
# Searching for bug ID: HIVE-22208 (Version: 3.1.0)
# Searching for bug ID: HIVE-22197 (Version: 4.0.0)
# Searching for bug ID: HIVE-22170 (Version: 3.1.2)
# Searching for bug ID: HIVE-22164 (Version: 4.0.0)
# Searching for bug ID: HIVE-22161 (Version: 3.1.2)
# Searching for bug ID: HIVE-22124 (Version: 4.0.0)
# Searching for bug ID: HIVE-22121 (Version: 3.1.0)
# Searching for bug ID: HIVE-22120 (Version: 4.0.0)
# Searching for bug ID: HIVE-22110 (Version: 4.0.0)
# Searching for bug ID: HIVE-22109 (Version: 4.0.0)
# Searching for bug ID: HIVE-22107 (Version: 4.0.0)
# Searching for bug ID: HIVE-22080 (Version: 4.0.0)
# Searching for bug ID: HIVE-22076 (Version: 4.0.0)
# Searching for bug ID: HIVE-22075 (Version: 3.1.1)
# Searching for bug ID: HIVE-22056 (Version: 3.1.0)
# Searching for bug ID: HIVE-22045 (Version: 4.0.0)
# Searching for bug ID: HIVE-22009 (Version: 3.1.1)
# Searching for bug ID: HIVE-22008 (Version: 2.3.4)
# Searching for bug ID: HIVE-22007 (Version: 4.0.0)
# Searching for bug ID: HIVE-21992 (Version: 4.0.0)
# Searching for bug ID: HIVE-21976 (Version: 4.0.0)
# Searching for bug ID: HIVE-21970 (Version: 4.0.0)
# Searching for bug ID: HIVE-21957 (Version: 4.0.0)
# Searching for bug ID: HIVE-21951 (Version: 4.0.0)
# Searching for bug ID: HIVE-21925 (Version: 4.0.0)
# Searching for bug ID: HIVE-21913 (Version: 4.0.0)
# Searching for bug ID: HIVE-21892 (Version: 4.0.0)
# Searching for bug ID: HIVE-21880 (Version: 4.0.0)
# Searching for bug ID: HIVE-21879 (Version: 4.0.0)
# Searching for bug ID: HIVE-21862 (Version: 4.0.0)
# Searching for bug ID: HIVE-21825 (Version: 4.0.0)
# Searching for bug ID: HIVE-21811 (Version: 4.0.0)
# Searching for bug ID: HIVE-21786 (Version: 3.1.1)
# Searching for bug ID: HIVE-21778 (Version: 2.3.5)
# Searching for bug ID: HIVE-21776 (Version: 4.0.0)
# Searching for bug ID: HIVE-21768 (Version: 3.1.1)
# Searching for bug ID: HIVE-21750 (Version: 4.0.0)
# Searching for bug ID: HIVE-21730 (Version: 4.0.0)
# Searching for bug ID: HIVE-21729 (Version: 4.0.0)
# Searching for bug ID: HIVE-21722 (Version: 4.0.0)
# Searching for bug ID: HIVE-21717 (Version: 4.0.0)
# Searching for bug ID: HIVE-21711 (Version: 4.0.0)
# Searching for bug ID: HIVE-21706 (Version: 4.0.0)
# Searching for bug ID: HIVE-21700 (Version: 4.0.0)
# Searching for bug ID: HIVE-21694 (Version: 4.0.0)
# Searching for bug ID: HIVE-21677 (Version: 4.0.0)
# Searching for bug ID: HIVE-21669 (Version: 4.0.0)
# Searching for bug ID: HIVE-21654 (Version: 4.0.0)
# Searching for bug ID: HIVE-21632 (Version: 4.0.0)
# Searching for bug ID: HIVE-21624 (Version: 4.0.0)
# Searching for bug ID: HIVE-21597 (Version: 4.0.0)
# Searching for bug ID: HIVE-21594 (Version: 4.0.0)
# Searching for bug ID: HIVE-21591 (Version: 4.0.0)
# Searching for bug ID: HIVE-21582 (Version: 4.0.0)
# Searching for bug ID: HIVE-21564 (Version: 4.0.0)
# Searching for bug ID: HIVE-21539 (Version: 4.0.0)
# Searching for bug ID: HIVE-21531 (Version: 3.1.1)
# Searching for bug ID: HIVE-21513 (Version: 3.1.1)
# Searching for bug ID: HIVE-21497 (Version: 4.0.0)
# Searching for bug ID: HIVE-21496 (Version: 4.0.0)
# Searching for bug ID: HIVE-21482 (Version: 4.0.0)
# Searching for bug ID: HIVE-21471 (Version: 4.0.0)
# Searching for bug ID: HIVE-21460 (Version: 3.1.1)
# Searching for bug ID: HIVE-21450 (Version: 4.0.0)
# Searching for bug ID: HIVE-21446 (Version: 4.0.0)
# Searching for bug ID: HIVE-21437 (Version: 4.0.0)
# Searching for bug ID: HIVE-21421 (Version: 4.0.0)
# Searching for bug ID: HIVE-21415 (Version: 4.0.0)
# Searching for bug ID: HIVE-21407 (Version: 4.0.0)
# Searching for bug ID: HIVE-21403 (Version: 4.0.0)
# Searching for bug ID: HIVE-21402 (Version: 4.0.0)
# Searching for bug ID: HIVE-21400 (Version: 4.0.0)
# Searching for bug ID: HIVE-21391 (Version: 4.0.0)
# Searching for bug ID: HIVE-21390 (Version: 4.0.0)
# Searching for bug ID: HIVE-21387 (Version: 4.0.0)
# Searching for bug ID: HIVE-21344 (Version: 4.0.0)
# Searching for bug ID: HIVE-21343 (Version: 4.0.0)
# Searching for bug ID: HIVE-21340 (Version: 4.0.0)
# Searching for bug ID: HIVE-21339 (Version: 4.0.0)
# Searching for bug ID: HIVE-21327 (Version: 4.0.0)
# Searching for bug ID: HIVE-21325 (Version: 4.0.0)
# Searching for bug ID: HIVE-21320 (Version: 4.0.0)
# Searching for bug ID: HIVE-21307 (Version: 4.0.0)
# Searching for bug ID: HIVE-21306 (Version: 4.0.0)
# Searching for bug ID: HIVE-21301 (Version: 4.0.0)
# Searching for bug ID: HIVE-21293 (Version: 4.0.0)
# Searching for bug ID: HIVE-21286 (Version: 4.0.0)
# Searching for bug ID: HIVE-21284 (Version: 4.0.0)
# Searching for bug ID: HIVE-21281 (Version: 4.0.0)
# Searching for bug ID: HIVE-21269 (Version: 4.0.0)
# Searching for bug ID: HIVE-21261 (Version: 4.0.0)
# Searching for bug ID: HIVE-21260 (Version: 4.0.0)
# Searching for bug ID: HIVE-21257 (Version: 3.1.1)
# Searching for bug ID: HIVE-21254 (Version: 4.0.0)
# Searching for bug ID: HIVE-21244 (Version: 4.0.0)
# Searching for bug ID: HIVE-21235 (Version: 4.0.0)
# Searching for bug ID: HIVE-21233 (Version: 4.0.0)
# Searching for bug ID: HIVE-21232 (Version: 4.0.0)
# Searching for bug ID: HIVE-21227 (Version: 4.0.0)
# Searching for bug ID: HIVE-21223 (Version: 4.0.0)
# Searching for bug ID: HIVE-21222 (Version: 4.0.0)
# Searching for bug ID: HIVE-21212 (Version: 4.0.0)
# Searching for bug ID: HIVE-21206 (Version: 4.0.0)
# Searching for bug ID: HIVE-21186 (Version: 4.0.0)
# Searching for bug ID: HIVE-21132 (Version: 4.0.0)
# Searching for bug ID: HIVE-21114 (Version: 4.0.0)
# Searching for bug ID: HIVE-21104 (Version: 2.3.0)
# Searching for bug ID: HIVE-21103 (Version: 4.0.0)
# Searching for bug ID: HIVE-21086 (Version: 4.0.0)
# Searching for bug ID: HIVE-21036 (Version: 4.0.0)
# Searching for bug ID: HIVE-21035 (Version: 4.0.0)
# Searching for bug ID: HIVE-21022 (Version: 4.0.0)
# Searching for bug ID: HIVE-21019 (Version: 4.0.0)
# Searching for bug ID: HIVE-20989 (Version: 4.0.0)
# Searching for bug ID: HIVE-20988 (Version: 4.0.0)
# Searching for bug ID: HIVE-20969 (Version: 4.0.0)
# Searching for bug ID: HIVE-20955 (Version: 4.0.0)
# Searching for bug ID: HIVE-20953 (Version: 4.0.0)
# Searching for bug ID: HIVE-20951 (Version: 3.1.1)
# Searching for bug ID: HIVE-20948 (Version: 4.0.0)
# Searching for bug ID: HIVE-20926 (Version: 4.0.0)
# Searching for bug ID: HIVE-20916 (Version: 4.0.0)
# Searching for bug ID: HIVE-20915 (Version: 4.0.0)
# Searching for bug ID: HIVE-20911 (Version: 4.0.0)
# Searching for bug ID: HIVE-20910 (Version: 4.0.0)
# Searching for bug ID: HIVE-20905 (Version: 4.0.0)
# Searching for bug ID: HIVE-20901 (Version: 4.0.0)
# Searching for bug ID: HIVE-20870 (Version: 4.0.0)
# Searching for bug ID: HIVE-20842 (Version: 4.0.0)
# Searching for bug ID: HIVE-20841 (Version: 4.0.0)
# Searching for bug ID: HIVE-20833 (Version: 4.0.0)
# Searching for bug ID: HIVE-20817 (Version: 4.0.0)
# Searching for bug ID: HIVE-20806 (Version: 4.0.0)
# Searching for bug ID: HIVE-20805 (Version: 4.0.0)
# Searching for bug ID: HIVE-20801 (Version: 4.0.0)
# Searching for bug ID: HIVE-20762 (Version: 4.0.0)
# Searching for bug ID: HIVE-20761 (Version: 4.0.0)
# Searching for bug ID: HIVE-20757 (Version: 4.0.0)
# Searching for bug ID: HIVE-20742 (Version: 4.0.0)
# Searching for bug ID: HIVE-20719 (Version: 4.0.0)
# Searching for bug ID: HIVE-20682 (Version: 4.0.0)
# Searching for bug ID: HIVE-20680 (Version: 4.0.0)
# Searching for bug ID: HIVE-20678 (Version: 4.0.0)
# Searching for bug ID: HIVE-20676 (Version: 4.0.0)
# Searching for bug ID: HIVE-20656 (Version: 4.0.0)
# Searching for bug ID: HIVE-20649 (Version: 4.0.0)
# Searching for bug ID: HIVE-20648 (Version: 4.0.0)
# Searching for bug ID: HIVE-20636 (Version: 4.0.0)
# Searching for bug ID: HIVE-20632 (Version: 4.0.0)
# Searching for bug ID: HIVE-20631 (Version: 4.0.0)
# Searching for bug ID: HIVE-20629 (Version: 4.0.0)
# Searching for bug ID: HIVE-20627 (Version: 4.0.0)
# Searching for bug ID: HIVE-20621 (Version: 4.0.0)
# Searching for bug ID: HIVE-20612 (Version: 4.0.0)
# Searching for bug ID: HIVE-20610 (Version: 4.0.0)
# Searching for bug ID: HIVE-20607 (Version: 3.1.0)
# Searching for bug ID: HIVE-20601 (Version: 4.0.0)
# Searching for bug ID: HIVE-20595 (Version: 4.0.0)
# Searching for bug ID: HIVE-20583 (Version: 4.0.0)
# Searching for bug ID: HIVE-20582 (Version: 4.0.0)
# Searching for bug ID: HIVE-20577 (Version: 4.0.0)
# Searching for bug ID: HIVE-20563 (Version: 4.0.0)
# Searching for bug ID: HIVE-20561 (Version: 4.0.0)
# Searching for bug ID: HIVE-20544 (Version: 4.0.0)
# Searching for bug ID: HIVE-20542 (Version: 4.0.0)
# Searching for bug ID: HIVE-20541 (Version: 4.0.0)
# Searching for bug ID: HIVE-20511 (Version: 4.0.0)
# Searching for bug ID: HIVE-20505 (Version: 4.0.0)
# Searching for bug ID: HIVE-20472 (Version: 4.0.0)
# Searching for bug ID: HIVE-20470 (Version: 4.0.0)
# Searching for bug ID: HIVE-20451 (Version: 4.0.0)
# Searching for bug ID: HIVE-20394 (Version: 4.0.0)
# Searching for bug ID: HIVE-20385 (Version: 4.0.0)
# Searching for bug ID: HIVE-20361 (Version: 4.0.0)
# Searching for bug ID: HIVE-20347 (Version: 4.0.0)
# Searching for bug ID: HIVE-20281 (Version: 4.0.0)
# Searching for bug ID: HIVE-20277 (Version: 4.0.0)
# Searching for bug ID: HIVE-20274 (Version: 4.0.0)
# Searching for bug ID: HIVE-20258 (Version: 4.0.0)
# Searching for bug ID: HIVE-20226 (Version: 4.0.0)
# Searching for bug ID: HIVE-20209 (Version: 3.1.0)
# Searching for bug ID: HIVE-20192 (Version: 3.1.0)
# Searching for bug ID: HIVE-20179 (Version: 4.0.0)
# Searching for bug ID: HIVE-20168 (Version: 4.0.0)
# Searching for bug ID: HIVE-20165 (Version: 4.0.0)
# Searching for bug ID: HIVE-20147 (Version: 4.0.0)
# Searching for bug ID: HIVE-20129 (Version: 4.0.0)
# Searching for bug ID: HIVE-20126 (Version: 4.0.0)
# Searching for bug ID: HIVE-20116 (Version: 4.0.0)
# Searching for bug ID: HIVE-20103 (Version: 4.0.0)
# Searching for bug ID: HIVE-20101 (Version: 4.0.0)
# Searching for bug ID: HIVE-20098 (Version: 4.0.0)
# Searching for bug ID: HIVE-20074 (Version: 4.0.0)
# Searching for bug ID: HIVE-20066 (Version: 3.1.0)
# Searching for bug ID: HIVE-20059 (Version: 3.1.0)
# Searching for bug ID: HIVE-20028 (Version: 4.0.0)
# Searching for bug ID: HIVE-20016 (Version: 4.0.0)
# Searching for bug ID: HIVE-20004 (Version: 3.1.0)
# Searching for bug ID: HIVE-19980 (Version: 3.1.0)
# Searching for bug ID: HIVE-19964 (Version: 3.1.0)
# Searching for bug ID: HIVE-19956 (Version: 3.1.0)
# Searching for bug ID: HIVE-19907 (Version: 3.1.0)
# Searching for bug ID: HIVE-19903 (Version: 4.0.0)
# Searching for bug ID: HIVE-19887 (Version: 4.0.0)
# Searching for bug ID: HIVE-19886 (Version: 3.1.0)
# Searching for bug ID: HIVE-19877 (Version: 3.1.0)
# Searching for bug ID: HIVE-19876 (Version: 3.1.0)
# Searching for bug ID: HIVE-19875 (Version: 3.1.0)
# Searching for bug ID: HIVE-19873 (Version: 3.1.0)
# Searching for bug ID: HIVE-19864 (Version: 3.1.0)
# Searching for bug ID: HIVE-19817 (Version: 3.1.0)
# Searching for bug ID: HIVE-19814 (Version: 2.3.0)
# Searching for bug ID: HIVE-19794 (Version: 3.1.0)
# Searching for bug ID: HIVE-19792 (Version: 4.0.0)
# Searching for bug ID: HIVE-19773 (Version: 3.1.0)
# Searching for bug ID: HIVE-19772 (Version: 3.1.0)
# Searching for bug ID: HIVE-19726 (Version: 3.1.0)
# Searching for bug ID: HIVE-19701 (Version: 4.0.0)
# Searching for bug ID: HIVE-19664 (Version: 4.0.0)
# Searching for bug ID: HIVE-18871 (Version: 4.0.0)
# Searching for bug ID: HIVE-18767 (Version: 3.1.0)
# Searching for bug ID: HIVE-15406 (Version: 4.0.0)
# Searching for bug ID: HIVE-15190 (Version: 2.1.0)
# Searching for bug ID: HIVE-16554 (Version: 2.1.1)
# Searching for bug ID: HIVE-16239 (Version: 2.1.1)
# Searching for bug ID: HIVE-16107 (Version: 2.1.1)
# Searching for bug ID: HIVE-15105 (Version: 2.0.1)
# Searching for bug ID: HIVE-15090 (Version: 2.1.0)
# Searching for bug ID: HIVE-14903 (Version: 2.0.1)
# Searching for bug ID: HIVE-14829 (Version: 2.1.0)
# Searching for bug ID: HIVE-14820 (Version: 2.0.1)
# Searching for bug ID: HIVE-14805 (Version: 2.0.1)
# Searching for bug ID: HIVE-14566 (Version: 2.1.0)
# Searching for bug ID: HIVE-14433 (Version: 2.2.0)
# Searching for bug ID: HIVE-14223 (Version: 2.2.0)
# Searching for bug ID: HIVE-14164 (Version: 2.1.0)
# Searching for bug ID: HIVE-14074 (Version: 2.0.1)
# Searching for bug ID: HIVE-14049 (Version: 2.0.1)
# Searching for bug ID: HIVE-14032 (Version: 2.0.1)
# Searching for bug ID: HIVE-14019 (Version: 2.0.1)
# Searching for bug ID: HIVE-13987 (Version: 2.0.1)
# Searching for bug ID: HIVE-13904 (Version: 2.1.0)
# Searching for bug ID: HIVE-13883 (Version: 2.0.1)
# Searching for bug ID: HIVE-13621 (Version: 2.1.0)
# Searching for bug ID: HIVE-13494 (Version: 2.1.0)
# Searching for bug ID: HIVE-13264 (Version: 2.0.1)
# Searching for bug ID: HIVE-13197 (Version: 2.1.0)
# Searching for bug ID: HIVE-22093 (Version: 2.3.5)
# Searching for bug ID: HIVE-22054 (Version: 2.1.0)
# Searching for bug ID: HIVE-22044 (Version: 2.3.5)
# Searching for bug ID: HIVE-22033 (Version: 2.3.5)
# Searching for bug ID: HIVE-21969 (Version: 2.3.5)
# Searching for bug ID: HIVE-21809 (Version: 2.3.5)
# Searching for bug ID: HIVE-25968 (Version: 2.1.1)
# Searching for bug ID: HIVE-25262 (Version: 2.1.1)
# Searching for bug ID: HIVE-23489 (Version: 2.1.1)
# Searching for bug ID: HIVE-22664 (Version: 2.1.1)
# Searching for bug ID: HIVE-22601 (Version: 3.1.2)
# Searching for bug ID: HIVE-21185 (Version: 2.3.0)
# Searching for bug ID: HIVE-21111 (Version: 2.3.4)
# Searching for bug ID: HIVE-20843 (Version: 2.1.1)
# Searching for bug ID: HIVE-20756 (Version: 2.1.1)
# Searching for bug ID: HIVE-20331 (Version: 2.1.1)
# Searching for bug ID: HIVE-20172 (Version: 2.1.1)
# Searching for bug ID: HIVE-19202 (Version: 2.1.1)
# Searching for bug ID: HIVE-18859 (Version: 2.1.1)
# Searching for bug ID: HIVE-18829 (Version: 2.1.1)
# Searching for bug ID: HIVE-18390 (Version: 2.1.1)
# Searching for bug ID: HIVE-18293 (Version: 2.1.1)
# Searching for bug ID: HIVE-18234 (Version: 2.1.1)
# Searching for bug ID: HIVE-17942 (Version: 2.1.1)
# Searching for bug ID: HIVE-17832 (Version: 2.1.1)
# Searching for bug ID: HIVE-17764 (Version: 2.1.1)
# Searching for bug ID: HIVE-17679 (Version: 2.1.1)
# Searching for bug ID: HIVE-17664 (Version: 2.1.0)
# Searching for bug ID: HIVE-17659 (Version: 2.1.0)
# Searching for bug ID: HIVE-17624 (Version: 2.1.1)
# Searching for bug ID: HIVE-17619 (Version: 2.1.1)
# Searching for bug ID: HIVE-17501 (Version: 2.2.0)
# Searching for bug ID: HIVE-17469 (Version: 2.1.1)
# Searching for bug ID: HIVE-17352 (Version: 2.2.0)
# Searching for bug ID: HIVE-17309 (Version: 2.2.0)
# Searching for bug ID: HIVE-17272 (Version: 2.1.1)
# Searching for bug ID: HIVE-17189 (Version: 2.1.1)
# Searching for bug ID: HIVE-17148 (Version: 2.1.1)
# Searching for bug ID: HIVE-17098 (Version: 2.1.1)
# Searching for bug ID: HIVE-17063 (Version: 2.2.0)
# Searching for bug ID: HIVE-17002 (Version: 2.1.1)
# Searching for bug ID: HIVE-16983 (Version: 2.1.1)
# Searching for bug ID: HIVE-16910 (Version: 2.1.1)
# Searching for bug ID: HIVE-16907 (Version: 2.1.1)
# Searching for bug ID: HIVE-16877 (Version: 2.1.1)
# Searching for bug ID: HIVE-16872 (Version: 2.1.1)
# Searching for bug ID: HIVE-16845 (Version: 2.1.1)
# Searching for bug ID: HIVE-16828 (Version: 2.2.0)
# Searching for bug ID: HIVE-16826 (Version: 2.1.1)
# Searching for bug ID: HIVE-16821 (Version: 2.1.1)
# Searching for bug ID: HIVE-16801 (Version: 2.1.1)
# Searching for bug ID: HIVE-16768 (Version: 2.1.1)
# Searching for bug ID: HIVE-16683 (Version: 2.2.0)
# Searching for bug ID: HIVE-16539 (Version: 2.1.1)
# Searching for bug ID: HIVE-16533 (Version: 2.1.1)
# Searching for bug ID: HIVE-16480 (Version: 2.2.0)
# Searching for bug ID: HIVE-16413 (Version: 2.1.1)
# Searching for bug ID: HIVE-16335 (Version: 2.2.0)
# Searching for bug ID: HIVE-16155 (Version: 2.1.1)
# Searching for bug ID: HIVE-16141 (Version: 2.2.0)
# Searching for bug ID: HIVE-16113 (Version: 2.2.0)
# Searching for bug ID: HIVE-16106 (Version: 2.1.1)
# Searching for bug ID: HIVE-16100 (Version: 2.2.0)
# Searching for bug ID: HIVE-16074 (Version: 2.1.1)
# Searching for bug ID: HIVE-16061 (Version: 2.1.1)
# Searching for bug ID: HIVE-15922 (Version: 2.1.1)
# ...
# Searching for bug ID: HIVE-19632 (Version: 3.1.0)
# Searching for bug ID: HIVE-19629 (Version: 3.1.0)
# Searching for bug ID: HIVE-19614 (Version: 3.1.0)
# Searching for bug ID: HIVE-19613 (Version: 3.1.0)
# Searching for bug ID: HIVE-19588 (Version: 3.1.0)
# Searching for bug ID: HIVE-19575 (Version: 3.1.0)
# Searching for bug ID: HIVE-19568 (Version: 3.1.0)
# Searching for bug ID: HIVE-19567 (Version: 3.1.0)
# Searching for bug ID: HIVE-19485 (Version: 3.1.0)
# Searching for bug ID: HIVE-19468 (Version: 3.1.0)
# Searching for bug ID: HIVE-19389 (Version: 3.1.0)
# Searching for bug ID: HIVE-19385 (Version: 3.1.0)
# Searching for bug ID: HIVE-19315 (Version: 3.1.0)
# Searching for bug ID: HIVE-19277 (Version: 3.1.0)
# Searching for bug ID: HIVE-19249 (Version: 3.1.0)
# Searching for bug ID: HIVE-19199 (Version: 3.1.0)
# Searching for bug ID: HIVE-19168 (Version: 3.1.0)
# Searching for bug ID: HIVE-18874 (Version: 3.1.0)
# Searching for bug ID: HIVE-26209 (Version: 2.3.6)
# Searching for bug ID: HIVE-23086 (Version: 2.3.6)
# Searching for bug ID: HIVE-22967 (Version: 3.1.2)
# Searching for bug ID: HIVE-22670 (Version: 3.1.2)
# Searching for bug ID: HIVE-22480 (Version: 2.3.6)
# Searching for bug ID: HIVE-22453 (Version: 3.1.2)
# Searching for bug ID: HIVE-22268 (Version: 3.1.2)
# Searching for bug ID: HIVE-22190 (Version: 3.1.2)
# Searching for bug ID: HIVE-20628 (Version: 2.1.0)
# Searching for bug ID: HIVE-20080 (Version: 2.1.0)
# Searching for bug ID: HIVE-19860 (Version: 2.1.0)
# Searching for bug ID: HIVE-19743 (Version: 2.1.0)
# Searching for bug ID: HIVE-19250 (Version: 2.1.0)
# Searching for bug ID: HIVE-19231 (Version: 2.1.0)
# Searching for bug ID: HIVE-19230 (Version: 2.1.0)
# Searching for bug ID: HIVE-18572 (Version: 2.1.0)
# Searching for bug ID: HIVE-18459 (Version: 2.1.0)
# Searching for bug ID: HIVE-17829 (Version: 2.1.0)
# Searching for bug ID: HIVE-17279 (Version: 2.1.0)
# Searching for bug ID: HIVE-16421 (Version: 2.1.0)
# Searching for bug ID: HIVE-16287 (Version: 2.1.0)
# Searching for bug ID: HIVE-16274 (Version: 2.1.0)
# Searching for bug ID: HIVE-16163 (Version: 2.1.0)
# Searching for bug ID: HIVE-15995 (Version: 2.1.0)
# Searching for bug ID: HIVE-15902 (Version: 2.1.0)
# Searching for bug ID: HIVE-15862 (Version: 2.1.0)
# Searching for bug ID: HIVE-15646 (Version: 2.1.0)
# Searching for bug ID: HIVE-15552 (Version: 2.1.0)
# Searching for bug ID: HIVE-15531 (Version: 2.1.0)
# Searching for bug ID: HIVE-15498 (Version: 2.1.0)
# Searching for bug ID: HIVE-15443 (Version: 2.1.0)
# Searching for bug ID: HIVE-15402 (Version: 2.1.0)
# Searching for bug ID: HIVE-15308 (Version: 2.1.0)
# Searching for bug ID: HIVE-15291 (Version: 2.1.0)
# Searching for bug ID: HIVE-15267 (Version: 2.1.0)
# Searching for bug ID: HIVE-15239 (Version: 2.1.0)
# Searching for bug ID: HIVE-15237 (Version: 2.1.0)
# Searching for bug ID: HIVE-15181 (Version: 2.1.0)
# Searching for bug ID: HIVE-15175 (Version: 2.1.0)
# Searching for bug ID: HIVE-15158 (Version: 2.1.0)
# Searching for bug ID: HIVE-15155 (Version: 2.1.0)
# Searching for bug ID: HIVE-15070 (Version: 2.1.0)
# Searching for bug ID: HIVE-15050 (Version: 2.1.0)
# Searching for bug ID: HIVE-15035 (Version: 2.1.0)
# Searching for bug ID: HIVE-15030 (Version: 2.1.0)
# Searching for bug ID: HIVE-15029 (Version: 2.1.0)
# Searching for bug ID: HIVE-14982 (Version: 2.1.0)
# Searching for bug ID: HIVE-14980 (Version: 2.1.0)
# Searching for bug ID: HIVE-14966 (Version: 2.1.0)
# Searching for bug ID: HIVE-14960 (Version: 2.1.0)
# Searching for bug ID: HIVE-14959 (Version: 2.1.0)
# Searching for bug ID: HIVE-14873 (Version: 2.1.0)
# Searching for bug ID: HIVE-14839 (Version: 2.1.0)
# Searching for bug ID: HIVE-14819 (Version: 2.1.0)
# Searching for bug ID: HIVE-14798 (Version: 2.1.0)
# Searching for bug ID: HIVE-14792 (Version: 2.1.0)
# Searching for bug ID: HIVE-14779 (Version: 2.1.0)
# Searching for bug ID: HIVE-14773 (Version: 2.1.0)
# Searching for bug ID: HIVE-14726 (Version: 2.1.0)
# Searching for bug ID: HIVE-14698 (Version: 2.1.0)
# Searching for bug ID: HIVE-14697 (Version: 2.1.0)
# Searching for bug ID: HIVE-14690 (Version: 2.1.0)
# Searching for bug ID: HIVE-14686 (Version: 2.1.0)
# Searching for bug ID: HIVE-14674 (Version: 2.1.0)
# Searching for bug ID: HIVE-14619 (Version: 2.1.0)
# Searching for bug ID: HIVE-14617 (Version: 2.1.0)
# Searching for bug ID: HIVE-14591 (Version: 2.1.0)
# Searching for bug ID: HIVE-14564 (Version: 2.1.0)
# Searching for bug ID: HIVE-14563 (Version: 2.1.0)
# Searching for bug ID: HIVE-14557 (Version: 2.1.0)
# Searching for bug ID: HIVE-14530 (Version: 2.1.0)
# Searching for bug ID: HIVE-14529 (Version: 2.1.0)
# Searching for bug ID: HIVE-14483 (Version: 2.1.0)
# Searching for bug ID: HIVE-14481 (Version: 2.1.0)
# Searching for bug ID: HIVE-14463 (Version: 2.1.0)
# Searching for bug ID: HIVE-14424 (Version: 2.1.0)
# Searching for bug ID: HIVE-14416 (Version: 2.1.0)
# Searching for bug ID: HIVE-14394 (Version: 2.1.0)
# Searching for bug ID: HIVE-14338 (Version: 2.1.0)
# Searching for bug ID: HIVE-14330 (Version: 2.1.0)
# Searching for bug ID: HIVE-14308 (Version: 2.1.0)
# Searching for bug ID: HIVE-14295 (Version: 2.1.0)
# Searching for bug ID: HIVE-14294 (Version: 2.1.0)
# Searching for bug ID: HIVE-14293 (Version: 2.1.0)
# Searching for bug ID: HIVE-14292 (Version: 2.1.0)
# Searching for bug ID: HIVE-14274 (Version: 2.1.0)
# Searching for bug ID: HIVE-14258 (Version: 2.1.0)
# Searching for bug ID: HIVE-14254 (Version: 2.1.0)
# Searching for bug ID: HIVE-14244 (Version: 2.1.0)
# Searching for bug ID: HIVE-14234 (Version: 2.1.0)
# Searching for bug ID: HIVE-14192 (Version: 2.1.0)
# Searching for bug ID: HIVE-14175 (Version: 2.1.0)
# Searching for bug ID: HIVE-14174 (Version: 2.1.0)
# Searching for bug ID: HIVE-14150 (Version: 2.1.0)
# Searching for bug ID: HIVE-14149 (Version: 2.1.0)
# Searching for bug ID: HIVE-14144 (Version: 2.1.0)
# Searching for bug ID: HIVE-14141 (Version: 2.1.0)
# Searching for bug ID: HIVE-14126 (Version: 2.1.0)
# Searching for bug ID: HIVE-14121 (Version: 2.1.0)
# Searching for bug ID: HIVE-14115 (Version: 2.1.0)
# Searching for bug ID: HIVE-14098 (Version: 2.1.0)
# Searching for bug ID: HIVE-14090 (Version: 2.1.0)
# Searching for bug ID: HIVE-14073 (Version: 2.1.0)
# Searching for bug ID: HIVE-14062 (Version: 2.1.0)
# Searching for bug ID: HIVE-14053 (Version: 2.1.0)
# Searching for bug ID: HIVE-14004 (Version: 2.1.0)
# Searching for bug ID: HIVE-14003 (Version: 2.1.0)
# Searching for bug ID: HIVE-13997 (Version: 2.1.0)
# Searching for bug ID: HIVE-13973 (Version: 2.1.0)
# Searching for bug ID: HIVE-13955 (Version: 2.1.0)
# Searching for bug ID: HIVE-13945 (Version: 2.1.0)
# Searching for bug ID: HIVE-13934 (Version: 2.1.0)
# Searching for bug ID: HIVE-13929 (Version: 2.1.0)
# Searching for bug ID: HIVE-13928 (Version: 2.1.0)
# Searching for bug ID: HIVE-13914 (Version: 2.1.0)
# Searching for bug ID: HIVE-13912 (Version: 2.1.0)
# Searching for bug ID: HIVE-13911 (Version: 2.1.0)
# Searching for bug ID: HIVE-13889 (Version: 2.1.0)
# Searching for bug ID: HIVE-13887 (Version: 2.1.0)
# Searching for bug ID: HIVE-13882 (Version: 2.1.0)
# Searching for bug ID: HIVE-13878 (Version: 2.1.0)
# Searching for bug ID: HIVE-13876 (Version: 2.1.0)
# Searching for bug ID: HIVE-13872 (Version: 2.1.0)
# Searching for bug ID: HIVE-13871 (Version: 2.1.0)
# Searching for bug ID: HIVE-13867 (Version: 2.1.0)
# Searching for bug ID: HIVE-13863 (Version: 2.1.0)
# Searching for bug ID: HIVE-13861 (Version: 2.1.0)
# Searching for bug ID: HIVE-13859 (Version: 2.1.0)
# Searching for bug ID: HIVE-13845 (Version: 2.1.0)
# Searching for bug ID: HIVE-13841 (Version: 2.1.0)
# Searching for bug ID: HIVE-13840 (Version: 2.1.0)
# Searching for bug ID: HIVE-13834 (Version: 2.1.0)
# Searching for bug ID: HIVE-13832 (Version: 2.1.0)
# Searching for bug ID: HIVE-13831 (Version: 2.1.0)
# Searching for bug ID: HIVE-13821 (Version: 2.1.0)
# Searching for bug ID: HIVE-13818 (Version: 2.1.0)
# Searching for bug ID: HIVE-13784 (Version: 2.1.0)
# Searching for bug ID: HIVE-13779 (Version: 2.1.0)
# Searching for bug ID: HIVE-13777 (Version: 2.1.0)
# Searching for bug ID: HIVE-13767 (Version: 2.1.0)
# Searching for bug ID: HIVE-13753 (Version: 2.1.0)
# Searching for bug ID: HIVE-13751 (Version: 2.1.0)
# Searching for bug ID: HIVE-13743 (Version: 2.1.0)
# Searching for bug ID: HIVE-13730 (Version: 2.1.0)
# Searching for bug ID: HIVE-13728 (Version: 2.1.0)
# Searching for bug ID: HIVE-13720 (Version: 2.1.0)
# Searching for bug ID: HIVE-13719 (Version: 2.1.0)
# Searching for bug ID: HIVE-13712 (Version: 2.1.0)
# Searching for bug ID: HIVE-13705 (Version: 2.1.0)
# Searching for bug ID: HIVE-13702 (Version: 2.1.0)
# Searching for bug ID: HIVE-13701 (Version: 2.1.0)
# Searching for bug ID: HIVE-13700 (Version: 2.1.0)
# Searching for bug ID: HIVE-13686 (Version: 2.1.0)
# Searching for bug ID: HIVE-13683 (Version: 2.1.0)
# Searching for bug ID: HIVE-13671 (Version: 2.1.0)
# Searching for bug ID: HIVE-13645 (Version: 2.1.0)
# Searching for bug ID: HIVE-13628 (Version: 2.1.0)
# Searching for bug ID: HIVE-13622 (Version: 2.1.0)
# Searching for bug ID: HIVE-13600 (Version: 2.1.0)
# Searching for bug ID: HIVE-13599 (Version: 2.1.0)
# Searching for bug ID: HIVE-13572 (Version: 2.1.0)
# Searching for bug ID: HIVE-13563 (Version: 2.1.0)
# Searching for bug ID: HIVE-13533 (Version: 2.1.0)
# Searching for bug ID: HIVE-13510 (Version: 2.1.0)
# Searching for bug ID: HIVE-13488 (Version: 2.1.0)
# Searching for bug ID: HIVE-13487 (Version: 2.1.0)
# Searching for bug ID: HIVE-13485 (Version: 2.1.0)
# Searching for bug ID: HIVE-13458 (Version: 2.1.0)
# Searching for bug ID: HIVE-13438 (Version: 2.1.0)
# Searching for bug ID: HIVE-13434 (Version: 2.1.0)
# Searching for bug ID: HIVE-13396 (Version: 2.1.0)
# Searching for bug ID: HIVE-13388 (Version: 2.1.0)
# Searching for bug ID: HIVE-13343 (Version: 2.1.0)
# Searching for bug ID: HIVE-13342 (Version: 2.1.0)
# Searching for bug ID: HIVE-13327 (Version: 2.1.0)
# Searching for bug ID: HIVE-13325 (Version: 2.1.0)
# Searching for bug ID: HIVE-13291 (Version: 2.1.0)
# Searching for bug ID: HIVE-13287 (Version: 2.1.0)
# Searching for bug ID: HIVE-13284 (Version: 2.1.0)
# Searching for bug ID: HIVE-13269 (Version: 2.1.0)
# Searching for bug ID: HIVE-13267 (Version: 2.1.0)
# Searching for bug ID: HIVE-13262 (Version: 2.1.0)
# Searching for bug ID: HIVE-13258 (Version: 2.1.0)
# Searching for bug ID: HIVE-13256 (Version: 2.1.0)
# Searching for bug ID: HIVE-13255 (Version: 2.1.0)
# Searching for bug ID: HIVE-13251 (Version: 2.1.0)
# Searching for bug ID: HIVE-13246 (Version: 2.1.0)
# Searching for bug ID: HIVE-13245 (Version: 2.1.0)
# Searching for bug ID: HIVE-13242 (Version: 2.1.0)
# Searching for bug ID: HIVE-13233 (Version: 2.1.0)
# Searching for bug ID: HIVE-13227 (Version: 2.1.0)
# Searching for bug ID: HIVE-13223 (Version: 2.1.0)
# Searching for bug ID: HIVE-13210 (Version: 2.1.0)
# Searching for bug ID: HIVE-13209 (Version: 2.1.0)
# Searching for bug ID: HIVE-13199 (Version: 2.1.0)
# Searching for bug ID: HIVE-13190 (Version: 2.1.0)
# Searching for bug ID: HIVE-13185 (Version: 2.1.0)
# Searching for bug ID: HIVE-13153 (Version: 2.1.0)
# Searching for bug ID: HIVE-13135 (Version: 2.1.0)
# Searching for bug ID: HIVE-13128 (Version: 2.1.0)
# Searching for bug ID: HIVE-13119 (Version: 2.1.0)
# Searching for bug ID: HIVE-13110 (Version: 2.1.0)
# Searching for bug ID: HIVE-13109 (Version: 2.1.0)
# Searching for bug ID: HIVE-13100 (Version: 2.1.0)
# Searching for bug ID: HIVE-13089 (Version: 2.1.0)
# Searching for bug ID: HIVE-13087 (Version: 2.1.0)
# Searching for bug ID: HIVE-13086 (Version: 2.1.0)
# Searching for bug ID: HIVE-13079 (Version: 2.1.0)
# Searching for bug ID: HIVE-13077 (Version: 2.1.0)
# Searching for bug ID: HIVE-13070 (Version: 2.1.0)
# Searching for bug ID: HIVE-13016 (Version: 2.1.0)
# Searching for bug ID: HIVE-13015 (Version: 2.1.0)
# Searching for bug ID: HIVE-12995 (Version: 2.1.0)
# Searching for bug ID: HIVE-12990 (Version: 2.1.0)
# Searching for bug ID: HIVE-12980 (Version: 2.1.0)
# Searching for bug ID: HIVE-12881 (Version: 2.1.0)
# Searching for bug ID: HIVE-12846 (Version: 2.1.0)
# Searching for bug ID: HIVE-12837 (Version: 2.1.0)
# Searching for bug ID: HIVE-12812 (Version: 2.1.0)
# Searching for bug ID: HIVE-12792 (Version: 2.1.0)
# Searching for bug ID: HIVE-12757 (Version: 2.1.0)
# Searching for bug ID: HIVE-12752 (Version: 2.1.0)
# Searching for bug ID: HIVE-12656 (Version: 2.1.0)
# Searching for bug ID: HIVE-12644 (Version: 2.1.0)
# Searching for bug ID: HIVE-12635 (Version: 2.1.0)
# Searching for bug ID: HIVE-12614 (Version: 2.1.0)
# Searching for bug ID: HIVE-12165 (Version: 2.1.0)
# Searching for bug ID: HIVE-7239 (Version: 2.1.0)
# Searching for bug ID: HIVE-27960 (Version: 2.3.9)
# Searching for bug ID: HIVE-27315 (Version: 3.1.2)
# Searching for bug ID: HIVE-26872 (Version: 3.1.2)
# Searching for bug ID: HIVE-26434 (Version: 2.3.9)
# Searching for bug ID: HIVE-27140 (Version: 3.1.2)
# Searching for bug ID: HIVE-26114 (Version: 3.1.2)
# Searching for bug ID: HIVE-25561 (Version: 2.3.8)
# Searching for bug ID: HIVE-24553 (Version: 2.3.8)
# Searching for bug ID: HIVE-24551 (Version: 2.3.8)
# Searching for bug ID: HIVE-24512 (Version: 2.3.8)
# Searching for bug ID: HIVE-28217 (Version: 3.1.2)
# Searching for bug ID: HIVE-27350 (Version: 3.1.2)
# Searching for bug ID: HIVE-26664 (Version: 3.1.2)
# Searching for bug ID: HIVE-26663 (Version: 3.1.2)
# Searching for bug ID: HIVE-26568 (Version: 3.1.2)
# Searching for bug ID: HIVE-26530 (Version: 3.1.2)
# Searching for bug ID: HIVE-26232 (Version: 3.1.2)
# Searching for bug ID: HIVE-25991 (Version: 3.1.2)
# Searching for bug ID: HIVE-25876 (Version: 3.1.2)
# Searching for bug ID: HIVE-25844 (Version: 3.1.2)
# Searching for bug ID: HIVE-25839 (Version: 3.1.2)
# Searching for bug ID: HIVE-25797 (Version: 3.1.2)
# Searching for bug ID: HIVE-25499 (Version: 3.1.2)
# Searching for bug ID: HIVE-25458 (Version: 3.1.2)
# Searching for bug ID: HIVE-25416 (Version: 3.1.2)
# Searching for bug ID: HIVE-25298 (Version: 3.1.2)
# Searching for bug ID: HIVE-25170 (Version: 3.1.2)
# Searching for bug ID: HIVE-25156 (Version: 3.1.2)
# Searching for bug ID: HIVE-25093 (Version: 3.1.2)
# Searching for bug ID: HIVE-25041 (Version: 3.1.2)
# Searching for bug ID: HIVE-24949 (Version: 3.1.2)
# Searching for bug ID: HIVE-24689 (Version: 3.1.2)
# Searching for bug ID: HIVE-24653 (Version: 3.1.2)
# Searching for bug ID: HIVE-24573 (Version: 3.1.2)
# Searching for bug ID: HIVE-24517 (Version: 3.1.2)
# Searching for bug ID: HIVE-24467 (Version: 2.3.4)
# Searching for bug ID: HIVE-24342 (Version: 3.1.2)
# Searching for bug ID: HIVE-24319 (Version: 3.1.2)
# Searching for bug ID: HIVE-24193 (Version: 3.1.2)
# Searching for bug ID: HIVE-24113 (Version: 3.1.2)
# Searching for bug ID: HIVE-24083 (Version: 3.1.2)
# Searching for bug ID: HIVE-23872 (Version: 3.1.2)
# Searching for bug ID: HIVE-23719 (Version: 3.1.2)
# Searching for bug ID: HIVE-23583 (Version: 3.1.2)
# Searching for bug ID: HIVE-23498 (Version: 3.1.2)
# Searching for bug ID: HIVE-23129 (Version: 3.1.2)
# Searching for bug ID: HIVE-23128 (Version: 3.1.2)
# Searching for bug ID: HIVE-23088 (Version: 3.1.2)
# Searching for bug ID: HIVE-22905 (Version: 3.1.2)
# Searching for bug ID: HIVE-22901 (Version: 3.1.2)
# Searching for bug ID: HIVE-22807 (Version: 3.1.2)
# Searching for bug ID: HIVE-22712 (Version: 3.1.2)
# Searching for bug ID: HIVE-22578 (Version: 3.1.2)
# Searching for bug ID: HIVE-22461 (Version: 3.1.2)
# Searching for bug ID: HIVE-22408 (Version: 3.1.2)
# Searching for bug ID: HIVE-22393 (Version: 3.1.2)
# Searching for bug ID: HIVE-22373 (Version: 3.1.2)
# Searching for bug ID: HIVE-22344 (Version: 3.1.2)
# Searching for bug ID: HIVE-22301 (Version: 3.1.2)
# Searching for bug ID: HIVE-22255 (Version: 3.1.2)
# Searching for bug ID: HIVE-22162 (Version: 3.1.2)
# Searching for bug ID: HIVE-21829 (Version: 3.1.2)
# Searching for bug ID: HIVE-21753 (Version: 3.1.2)
# Searching for bug ID: HIVE-21489 (Version: 2.3.4)
# Searching for bug ID: HIVE-24915 (Version: 2.3.4)
# Searching for bug ID: HIVE-24406 (Version: 2.3.4)
# Searching for bug ID: HIVE-21971 (Version: 2.3.4)
# Searching for bug ID: HIVE-21614 (Version: 2.3.4)
# Searching for bug ID: HIVE-21536 (Version: 2.3.4)
# Searching for bug ID: HIVE-21508 (Version: 2.3.4)
# Searching for bug ID: HIVE-21374 (Version: 2.3.4)
# Searching for bug ID: HIVE-21200 (Version: 2.3.4)
# Searching for bug ID: HIVE-21136 (Version: 2.3.4)
# Searching for bug ID: HIVE-16839 (Version: 2.3.4)

# %%
os.chdir(project_repo)
output_file = 'Hive_Modified_Files.csv'

try:
    with open(output_file, 'w+', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        for bug_id, data in bug_file_map.items():
            bug_id_str = str(bug_id)
            version_str = str(data['version'])
            files_str = ";".join(data['files'])
            writer.writerow([bug_id_str, version_str, files_str])
        print(f"Output has been written to {output_file}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Output has been written to Hive_Modified_Files.csv

# %% [markdown]
# ## 3. Gather Independant Variables for Each File in Each Version of Hive
#
# We will now use  *SciTools Understand* to collect a plethora of independent variables that will eventually help us predict bugs. First though, we need to retrieve the very last commit before the release of each version of the software.

# %% [markdown]
# From the [Apache Hive tags](https://github.com/apache/hive/tags), we can fetch manually the commit for each of the software version

# %%
hive_versions = {
    "2.0.0": "7f9f1fcb8697fb33f0edc2c391930a3728d247d7",
    "2.0.1": "e3cfeebcefe9a19c5055afdcbb00646908340694",
    "2.1.0": "9265bc24d75ac945bde9ce1a0999fddd8f2aae29",
    "2.1.1": "1af77bbf8356e86cabbed92cfa8cc2e1470a1d5c",
    "2.2.0": "da840b0f8fa99cab9f004810cd22abc207493cae",
    "2.3.0": "6f4c35c9e904d226451c465effdc5bfd31d395a0",
    "2.3.1": "7590572d9265e15286628013268b2ce785c6aa08",
    "2.3.2": "857a9fd8ad725a53bd95c1b2d6612f9b1155f44d",
    "2.3.3": "3f7dde31aed44b5440563d3f9d8a8887beccf0be",
    "2.3.4": "56acdd2120b9ce6790185c679223b8b5e884aaf2",
    "2.3.5": "76595628ae13b95162e77bba365fe4d2c60b3f29",
    "2.3.6": "2c2fdd524e8783f6e1f3ef15281cc2d5ed08728f",
    "2.3.7": "cb213d88304034393d68cc31a95be24f5aac62b6",
    "2.3.8": "f1e87137034e4ecbe39a859d4ef44319800016d7",
    "2.3.9": "92dd0159f440ca7863be3232f3a683a510a62b9d",
    "2.3.10": "5160d3af392248255f68e41e1e0557eae4d95273",
    "3.0.0": "ce61711a5fa54ab34fc74d86d521ecaeea6b072a",
    "3.1.0": "bcc7df95824831a8d2f1524e4048dfc23ab98c19",
    "3.1.1": "f4e0529634b6231a0072295da48af466cf2f10b7",
    "3.1.2": "8190d2be7b7165effa62bd21b7d60ef81fb0e4af",
    "3.1.3": "4df4d75bf1e16fe0af75aad0b4179c34c07fc975",
    "4.0.0": "183f8cb41d3dbed961ffd27999876468ff06690c",
    "4.0.1": "3af4517eb8cfd9407ad34ed78a0b48b57dfaa264"
}

# %% [markdown]
# These different release dates will allow us to associate a commit to specific a version of Hive

# %%
output_file = project_repo.joinpath("Hive_Last_Commits.csv")

with open(output_file, mode='w', newline='') as file:
    writer = csv.writer(file)

    writer.writerow(["Version", "Commit Hash"])

    for version, commit in hive_versions.items():
        writer.writerow([version, commit])

print("Derniers commits pour chaque version enregistrés dans 'Hive_Last_Commits.csv'")
# Out:
# Derniers commits pour chaque version enregistrés dans 'Hive_Last_Commits.csv'

# %% [markdown]
# Finally, we can collect UND data

# %%
version_file = project_repo.joinpath("Hive_Last_Commits.csv")
und_base = project_repo.joinpath("UND_projects")
settings_file_path = project_repo.joinpath("settings.xml")
hive_data = project_repo.joinpath('UND_hive_data')


os.chdir(project_repo)

def run_command(command):
    try:
        subprocess.run(command, shell=True, check=True)
    except subprocess.CalledProcessError as e:
        print(f"Command failed: {e.cmd}")

run_command(f'rm -rf {und_base} && mkdir {und_base}')
run_command(f'rm -rf {hive_data} && mkdir {hive_data}')


os.chdir(hive_repo)

def process_versions():
    with open(version_file, "r") as file:
        next(file)
        for line in file:
            if line.strip():
                version, commit_id = line.split(",")[0].strip(), line.split(",")[1].strip()              

                run_command(f"cd {hive_repo} && git checkout {commit_id}")
                print(f"Successfully checked out {commit_id} before {version}")

                
                und_project_path = f"{und_base}/UND_{version}.und"

                run_command(f"und create -languages java C++ {und_project_path}")

                destination_settings_file = f"{und_project_path}/settings.xml"

                if os.path.exists(destination_settings_file):
                    print(f"Removing existing settings.xml at {destination_settings_file}")
                    os.remove(destination_settings_file)

                run_command(f"cp {settings_file_path} {und_project_path}")

                # Redudancy here is to override SciTools Understand's automatic generation of files
                run_command(f"cp {settings_file_path} {destination_settings_file}")
                run_command(f"und settings -metricsOutputFile {hive_data.joinpath(f'UND_{version}.csv')} {und_project_path}")

                run_command(f"und add {hive_repo} {und_project_path}")
                run_command(f"cp {settings_file_path} {destination_settings_file}")
                run_command(f"und settings -metricsOutputFile {hive_data.joinpath(f'UND_{version}.csv')} {und_project_path}")

                run_command(f"und analyze {und_project_path}")
                run_command(f"cp {settings_file_path} {destination_settings_file}")
                run_command(f"und settings -metricsOutputFile {hive_data.joinpath(f'UND_{version}.csv')} {und_project_path}")

                run_command(f"und metrics {und_project_path}")
                
if __name__ == "__main__":
    process_versions()
# Out:
# Previous HEAD position was 3af4517eb8 Preparing for 4.0.1 release
# HEAD is now at 7f9f1fcb86 HIVE-13032: Hive services need HADOOP_CLIENT_OPTS for proper log4j2 initialization (Prasanth Jayachandran reviewed by Sergey Shelukhin)
# Successfully checked out 7f9f1fcb8697fb33f0edc2c391930a3728d247d7 before 2.0.0
# Previous HEAD position was 7f9f1fcb86 HIVE-13032: Hive services need HADOOP_CLIENT_OPTS for proper log4j2 initialization (Prasanth Jayachandran reviewed by Sergey Shelukhin)
# HEAD is now at e3cfeebcef Update release notes for Hive 2.0.1 RC1
# Successfully checked out e3cfeebcefe9a19c5055afdcbb00646908340694 before 2.0.1
# Previous HEAD position was e3cfeebcef Update release notes for Hive 2.0.1 RC1
# HEAD is now at 9265bc24d7 RELEASE_NOTES
# Successfully checked out 9265bc24d75ac945bde9ce1a0999fddd8f2aae29 before 2.1.0
# Previous HEAD position was 9265bc24d7 RELEASE_NOTES
# HEAD is now at 1af77bbf83 Release notes 2.1.1 (addendum)
# Successfully checked out 1af77bbf8356e86cabbed92cfa8cc2e1470a1d5c before 2.1.1
# Previous HEAD position was 1af77bbf83 Release notes 2.1.1 (addendum)
# HEAD is now at da840b0f8f Missed file when preparing for release
# Successfully checked out da840b0f8fa99cab9f004810cd22abc207493cae before 2.2.0
# Previous HEAD position was da840b0f8f Missed file when preparing for release
# HEAD is now at 6f4c35c9e9 Release Notes
# Successfully checked out 6f4c35c9e904d226451c465effdc5bfd31d395a0 before 2.3.0
# Previous HEAD position was 6f4c35c9e9 Release Notes
# HEAD is now at 7590572d92 Release Notes
# Previous HEAD position was 7590572d92 Release Notes
# HEAD is now at 857a9fd8ad Release Notes
# Previous HEAD position was 857a9fd8ad Release Notes
# HEAD is now at 3f7dde31ae Preparing for 2.3.3 release
# Successfully checked out 7590572d9265e15286628013268b2ce785c6aa08 before 2.3.1
# Successfully checked out 857a9fd8ad725a53bd95c1b2d6612f9b1155f44d before 2.3.2
# Successfully checked out 3f7dde31aed44b5440563d3f9d8a8887beccf0be before 2.3.3
# Previous HEAD position was 3f7dde31ae Preparing for 2.3.3 release
# HEAD is now at 56acdd2120 Preparing for 2.3.4 release
# Previous HEAD position was 56acdd2120 Preparing for 2.3.4 release
# HEAD is now at 76595628ae Preparing for 2.3.5 release.
# Successfully checked out 56acdd2120b9ce6790185c679223b8b5e884aaf2 before 2.3.4
# Successfully checked out 76595628ae13b95162e77bba365fe4d2c60b3f29 before 2.3.5
# Previous HEAD position was 76595628ae Preparing for 2.3.5 release.
# HEAD is now at 2c2fdd524e Updated release notes for 2.3.6
# Previous HEAD position was 2c2fdd524e Updated release notes for 2.3.6
# HEAD is now at cb213d8830 Updated release notes for 2.3.7 release
# Successfully checked out 2c2fdd524e8783f6e1f3ef15281cc2d5ed08728f before 2.3.6
# Successfully checked out cb213d88304034393d68cc31a95be24f5aac62b6 before 2.3.7
# Previous HEAD position was cb213d8830 Updated release notes for 2.3.7 release
# HEAD is now at f1e8713703 Updated release notes for 2.3.8 release RC3
# Previous HEAD position was f1e8713703 Updated release notes for 2.3.8 release RC3
# HEAD is now at 92dd0159f4 Updated release notes for 2.3.9 release
# Successfully checked out f1e87137034e4ecbe39a859d4ef44319800016d7 before 2.3.8
# Successfully checked out 92dd0159f440ca7863be3232f3a683a510a62b9d before 2.3.9
# Previous HEAD position was 92dd0159f4 Updated release notes for 2.3.9 release
# HEAD is now at 5160d3af39 Updated release notes for 2.3.10 release RC1
# Successfully checked out 5160d3af392248255f68e41e1e0557eae4d95273 before 2.3.10
# Previous HEAD position was 5160d3af39 Updated release notes for 2.3.10 release RC1
# HEAD is now at ce61711a5f Preparing for release 3.0.0 : Updated standalone-metastore's dependency on storage-api
# Successfully checked out ce61711a5fa54ab34fc74d86d521ecaeea6b072a before 3.0.0
# Previous HEAD position was ce61711a5f Preparing for release 3.0.0 : Updated standalone-metastore's dependency on storage-api
# HEAD is now at bcc7df9582 HIVE-20227: Exclude glassfish javax.el dependency(Vineet Garg, reviewed by Ashutosh Chauhan)
# Successfully checked out bcc7df95824831a8d2f1524e4048dfc23ab98c19 before 3.1.0
# Previous HEAD position was bcc7df9582 HIVE-20227: Exclude glassfish javax.el dependency(Vineet Garg, reviewed by Ashutosh Chauhan)
# HEAD is now at f4e0529634 Preparing for 3.1.1 release
# Successfully checked out f4e0529634b6231a0072295da48af466cf2f10b7 before 3.1.1
# Previous HEAD position was f4e0529634 Preparing for 3.1.1 release
# HEAD is now at 8190d2be7b Updated Release Notes with a couple of issues that were added late to the release.
# Successfully checked out 8190d2be7b7165effa62bd21b7d60ef81fb0e4af before 3.1.2
# Previous HEAD position was 8190d2be7b Updated Release Notes with a couple of issues that were added late to the release.
# HEAD is now at 4df4d75bf1 HIVE-25665: Checkstyle LGPL files must not be in the release sources/binaries (Peter Vary reviewed by Zoltan Haindrich) (#3063)
# Successfully checked out 4df4d75bf1e16fe0af75aad0b4179c34c07fc975 before 3.1.3
# Previous HEAD position was 4df4d75bf1 HIVE-25665: Checkstyle LGPL files must not be in the release sources/binaries (Peter Vary reviewed by Zoltan Haindrich) (#3063)
# HEAD is now at 183f8cb41d Updating RELEASE_NOTES, NOTICE, README.md for 4.0.0
# Successfully checked out 183f8cb41d3dbed961ffd27999876468ff06690c before 4.0.0
# Successfully checked out 3af4517eb8cfd9407ad34ed78a0b48b57dfaa264 before 4.0.1
# Previous HEAD position was 183f8cb41d Updating RELEASE_NOTES, NOTICE, README.md for 4.0.0
# HEAD is now at 3af4517eb8 Preparing for 4.0.1 release
