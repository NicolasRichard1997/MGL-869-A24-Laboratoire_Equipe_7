# %% [markdown]
# # Data Extraction
#
# This notebook contains all the steps necessary to fetch all bugs from the Apache Hive Jira online repository (available at [this address](https://issues.apache.org/jira/projects/HIVE/issues/HIVE-25351?filter=allopenissues)). We will begin by downloading the data to this repository before filtering it.

# %% [markdown]
# ## 1. Fetching Bug Reports from Jira
#
# The first steps is to download and copy all the bug reports from *Hive 2.0.0* and subsequent versions. [On this page](https://issues.apache.org/jira/projects/HIVE/issues/HIVE-25351?filter=allopenissues), we can select `Advanced Search` and copy the following command :
# ```sql
# project = HIVE AND issuetype = Bug AND status in (Resolved, Closed) AND affectedVersion = X.Y.Z
# ```
# to fetch the bugs from a specific report. Bug reports for major and minor versions, as well as patches, can be downloaded.All of the bugs reports are kept in the `Jira_bug_data` folder, present in this repository.

# %% [markdown]
# ## 2. Removing Redundant Bugs & Concatenating the Data
# Since a given bug may affect more than a single version of the software, some redundancy is present in the downloaded data. Although, we might not want to remove duplicates as we will find the affected files for a specific bug in multiple versions of the project. So, we will use pandas data frames to load all of the data from the bugs in the files before concatenating the bugs in a single file with their specific version number.

# %%
import pandas as pd
import os
import re
from pathlib import Path

# %% [markdown]
# In order to simplify repertory changes, we'll initialize two variables, containning the paths of this current repository and the path of your clone of the Apache Hive repertory

# %%
project_repo = "/home/nicolas-richard/Desktop/.Apache_Hive_Bug_Prediction_ML_Model/"
hive_repo = "/home/nicolas-richard/Desktop/.Apache_Hive/"

# %%
project_repo = Path(project_repo)
data_dir = project_repo.joinpath("Jira_bug_data")

version_pattern = re.compile(r'_(\d+\.\d+\.\d+)_')

bug_dfs = []

for file_path in data_dir.glob("*.csv"):
    
    df = pd.read_csv(file_path)

    filename = file_path.name  # e.g., 'Hive_3.3.0_Jira_Bug_Data.csv'

    match = version_pattern.search(filename)
    version = match.group(1) if match else 'Unknown'
    
    df['Version'] = version

    df = df[['Issue key', 'Version']]
   
    bug_dfs.append(df)

concatenated_bug_dfs = pd.concat(bug_dfs, ignore_index=True)

concatenated_bug_dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2133 entries, 0 to 2132
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Issue key  2133 non-null   object
#  1   Version    2133 non-null   object
# dtypes: object(2)
# memory usage: 33.5+ KB

# %% [markdown]
# We have gathered 2133 bugs. We will run a simple check to remove duplicate lines

# %%
combined_bug_dfs = concatenated_bug_dfs.drop_duplicates()

combined_bug_dfs.info()

combined_bug_dfs.to_csv("Hive_Jira_Bug_Data.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2133 entries, 0 to 2132
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Issue key  2133 non-null   object
#  1   Version    2133 non-null   object
# dtypes: object(2)
# memory usage: 33.5+ KB

# %% [markdown]
# Despite the above lines, some duplicate bug keys will remain, which is intentional. Those bugs affected more than a single version of the software. The below line of code outputs bugs affecting multiple versions

# %%
print(concatenated_bug_dfs['Issue key'].value_counts())
# Out:
# Issue key
# HIVE-21873    6
# HIVE-21009    6
# HIVE-18284    5
# HIVE-19101    5
# HIVE-17429    5
#              ..
# HIVE-22360    1
# HIVE-22375    1
# HIVE-22514    1
# HIVE-22537    1
# HIVE-22124    1
# Name: count, Length: 1771, dtype: int64

# %% [markdown]
# ## 2. Identified Affected Java and C++ Files
#
# The goal here will be, for every single bug ID collected above, to identify the java and C++ in a given version of the software. Make sure you have a cloned repo of the Apache Hive project on you computer and the path at hand.

# %%
import os
import csv
import subprocess

# %%
os.chdir(hive_repo)
subprocess.run(['git', 'checkout', "master"], check=True)
subprocess.run(['git', 'pull'], check=True)

bug_file_map = {}

with open(project_repo.joinpath("Hive_Jira_Bug_Data.csv"), 'r') as f:
    for line in f:
        bug_id, version = line.strip().split(',')
        bug_file_map[bug_id] = {'version': version, 'files': []}

for bug_id in bug_file_map:
    version = bug_file_map[bug_id]['version']
    print(f"Searching for bug ID: {bug_id} (Version: {version})")

    try:
        result = subprocess.run(
            ["git", "log", "--grep=" + bug_id, "--name-only", "--pretty=format:"],
            capture_output=True,
            text=True,
            check=True
        )

        all_files = result.stdout.splitlines()
        filtered_files = [file for file in all_files if file.endswith(('.cpp', '.java'))]

        if filtered_files:
            bug_file_map[bug_id]['files'].extend(filtered_files)

    except subprocess.CalledProcessError as e:
        print(f"Error searching for {bug_id}: {e}")
# Out:
# D	.asf.yaml
# M	.gitignore
# M	.reviewboardrc
# D	Jenkinsfile
# M	LICENSE
# D	LICENSE-binary
# M	NOTICE
# D	README.md
# M	RELEASE_NOTES.txt
# M	accumulo-handler/pom.xml
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/AccumuloConnectionParameters.java
# D	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/AccumuloDefaultIndexScanner.java
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/AccumuloHiveConstants.java
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/AccumuloHiveRow.java
# D	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/AccumuloIndexLexicoder.java
# D	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/AccumuloIndexScanner.java
# D	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/AccumuloIndexScannerException.java
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/AccumuloStorageHandler.java
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/HiveAccumuloHelper.java
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/columns/ColumnMapper.java
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/columns/ColumnMappingFactory.java
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/columns/HiveAccumuloMapColumnMapping.java
# D	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/mr/AccumuloIndexDefinition.java
# D	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/mr/AccumuloIndexedOutputFormat.java
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/mr/HiveAccumuloSplit.java
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/mr/HiveAccumuloTableInputFormat.java
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/mr/HiveAccumuloTableOutputFormat.java
# D	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/mr/IndexOutputConfigurator.java
# D	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/mr/package-info.java
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/package-info.java
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/predicate/AccumuloPredicateHandler.java
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/predicate/AccumuloRangeGenerator.java
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/predicate/PrimitiveComparisonFilter.java
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/predicate/PushdownTuple.java
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/predicate/compare/StringCompare.java
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/predicate/compare/package-info.java
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/predicate/package-info.java
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/serde/AccumuloCompositeRowId.java
# D	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/serde/AccumuloIndexParameters.java
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/serde/AccumuloSerDe.java
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/serde/AccumuloSerDeParameters.java
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/serde/CompositeAccumuloRowIdFactory.java
# M	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/serde/DefaultAccumuloRowIdFactory.java
# D	accumulo-handler/src/java/org/apache/hadoop/hive/accumulo/serde/package-info.java
# M	accumulo-handler/src/test/org/apache/hadoop/hive/accumulo/TestAccumuloConnectionParameters.java
# D	accumulo-handler/src/test/org/apache/hadoop/hive/accumulo/TestAccumuloDefaultIndexScanner.java
# D	accumulo-handler/src/test/org/apache/hadoop/hive/accumulo/TestAccumuloIndexLexicoder.java
# D	accumulo-handler/src/test/org/apache/hadoop/hive/accumulo/TestAccumuloIndexParameters.java
# M	accumulo-handler/src/test/org/apache/hadoop/hive/accumulo/TestAccumuloStorageHandler.java
# M	accumulo-handler/src/test/org/apache/hadoop/hive/accumulo/TestHiveAccumuloHelper.java
# M	accumulo-handler/src/test/org/apache/hadoop/hive/accumulo/columns/TestColumnMapper.java
# M	accumulo-handler/src/test/org/apache/hadoop/hive/accumulo/mr/TestHiveAccumuloTableInputFormat.java
# M	accumulo-handler/src/test/org/apache/hadoop/hive/accumulo/mr/TestHiveAccumuloTableOutputFormat.java
# M	accumulo-handler/src/test/org/apache/hadoop/hive/accumulo/mr/TestHiveAccumuloTypes.java
# M	accumulo-handler/src/test/org/apache/hadoop/hive/accumulo/predicate/TestAccumuloPredicateHandler.java
# M	accumulo-handler/src/test/org/apache/hadoop/hive/accumulo/predicate/TestAccumuloRangeGenerator.java
# M	accumulo-handler/src/test/org/apache/hadoop/hive/accumulo/predicate/TestPrimitiveComparisonFilter.java
# M	accumulo-handler/src/test/org/apache/hadoop/hive/accumulo/serde/FirstCharAccumuloCompositeRowId.java
# M	accumulo-handler/src/test/org/apache/hadoop/hive/accumulo/serde/TestAccumuloSerDe.java
# M	accumulo-handler/src/test/org/apache/hadoop/hive/accumulo/serde/TestDefaultAccumuloRowIdFactory.java
# M	accumulo-handler/src/test/queries/positive/accumulo_custom_key.q
# M	accumulo-handler/src/test/queries/positive/accumulo_custom_key2.q
# D	accumulo-handler/src/test/queries/positive/accumulo_index.q
# M	accumulo-handler/src/test/queries/positive/accumulo_joins.q
# M	accumulo-handler/src/test/queries/positive/accumulo_predicate_pushdown.q
# M	accumulo-handler/src/test/queries/positive/accumulo_queries.q
# M	accumulo-handler/src/test/queries/positive/accumulo_single_sourced_multi_insert.q
# M	accumulo-handler/src/test/results/positive/accumulo_custom_key.q.out
# M	accumulo-handler/src/test/results/positive/accumulo_custom_key2.q.out
# D	accumulo-handler/src/test/results/positive/accumulo_index.q.out
# M	accumulo-handler/src/test/results/positive/accumulo_predicate_pushdown.q.out
# M	accumulo-handler/src/test/results/positive/accumulo_queries.q.out
# M	accumulo-handler/src/test/results/positive/accumulo_single_sourced_multi_insert.q.out
# M	beeline/pom.xml
# M	beeline/src/java/org/apache/hive/beeline/AbstractCommandHandler.java
# M	beeline/src/java/org/apache/hive/beeline/AbstractOutputFormat.java
# M	beeline/src/java/org/apache/hive/beeline/BeeLine.java
# M	beeline/src/java/org/apache/hive/beeline/BeeLineCommandCompleter.java
# M	beeline/src/java/org/apache/hive/beeline/BeeLineCompleter.java
# M	beeline/src/java/org/apache/hive/beeline/BeeLineOpts.java
# M	beeline/src/java/org/apache/hive/beeline/BeeLineSignalHandler.java
# M	beeline/src/java/org/apache/hive/beeline/BooleanCompleter.java
# M	beeline/src/java/org/apache/hive/beeline/BufferedRows.java
# M	beeline/src/java/org/apache/hive/beeline/ClientCommandHookFactory.java
# M	beeline/src/java/org/apache/hive/beeline/ClientHook.java
# M	beeline/src/java/org/apache/hive/beeline/ColorBuffer.java
# M	beeline/src/java/org/apache/hive/beeline/CommandHandler.java
# M	beeline/src/java/org/apache/hive/beeline/Commands.java
# M	beeline/src/java/org/apache/hive/beeline/DatabaseConnection.java
# M	beeline/src/java/org/apache/hive/beeline/DatabaseConnections.java
# M	beeline/src/java/org/apache/hive/beeline/DeprecatedSeparatedValuesOutputFormat.java
# M	beeline/src/java/org/apache/hive/beeline/DriverInfo.java
# M	beeline/src/java/org/apache/hive/beeline/IncrementalRows.java
# D	beeline/src/java/org/apache/hive/beeline/IncrementalRowsWithNormalization.java
# D	beeline/src/java/org/apache/hive/beeline/JSONFileOutputFormat.java
# D	beeline/src/java/org/apache/hive/beeline/JSONOutputFormat.java
# M	beeline/src/java/org/apache/hive/beeline/OutputFile.java
# M	beeline/src/java/org/apache/hive/beeline/OutputFormat.java
# M	beeline/src/java/org/apache/hive/beeline/ReflectiveCommandHandler.java
# M	beeline/src/java/org/apache/hive/beeline/Reflector.java
# M	beeline/src/java/org/apache/hive/beeline/Rows.java
# M	beeline/src/java/org/apache/hive/beeline/SQLCompleter.java
# M	beeline/src/java/org/apache/hive/beeline/SeparatedValuesOutputFormat.java
# M	beeline/src/java/org/apache/hive/beeline/SunSignalHandler.java
# M	beeline/src/java/org/apache/hive/beeline/TableNameCompletor.java
# M	beeline/src/java/org/apache/hive/beeline/TableOutputFormat.java
# M	beeline/src/java/org/apache/hive/beeline/VerticalOutputFormat.java
# M	beeline/src/java/org/apache/hive/beeline/XMLAttributeOutputFormat.java
# M	beeline/src/java/org/apache/hive/beeline/XMLElementOutputFormat.java
# M	beeline/src/java/org/apache/hive/beeline/cli/CliOptionsProcessor.java
# M	beeline/src/java/org/apache/hive/beeline/cli/HiveCli.java
# M	beeline/src/main/resources/BeeLine.properties
# M	beeline/src/main/resources/beeline-log4j2.properties
# M	beeline/src/test/org/apache/hive/beeline/ProxyAuthTest.java
# D	beeline/src/test/org/apache/hive/beeline/TestBeeLineExceptionHandling.java
# D	beeline/src/test/org/apache/hive/beeline/TestBeeLineHistory.java
# D	beeline/src/test/org/apache/hive/beeline/TestBeeLineOpts.java
# M	beeline/src/test/org/apache/hive/beeline/TestBeelineArgParsing.java
# D	beeline/src/test/org/apache/hive/beeline/TestBufferedRows.java
# M	beeline/src/test/org/apache/hive/beeline/TestClientCommandHookFactory.java
# D	beeline/src/test/org/apache/hive/beeline/TestCommands.java
# D	beeline/src/test/org/apache/hive/beeline/TestIncrementalRows.java
# D	beeline/src/test/org/apache/hive/beeline/TestJSONFileOutputFormat.java
# D	beeline/src/test/org/apache/hive/beeline/TestJSONOutputFormat.java
# D	beeline/src/test/org/apache/hive/beeline/TestShutdownHook.java
# D	beeline/src/test/org/apache/hive/beeline/TestTableOutputFormat.java
# M	beeline/src/test/org/apache/hive/beeline/cli/TestHiveCli.java
# D	beeline/src/test/resources/beeline-site.xml
# M	beeline/src/test/resources/hive-site.xml
# D	beeline/src/test/resources/test-hs2-conn-conf-kerberos-http.xml
# D	beeline/src/test/resources/test-hs2-conn-conf-kerberos-nossl.xml
# D	beeline/src/test/resources/test-hs2-conn-conf-kerberos-ssl.xml
# D	beeline/src/test/resources/test-hs2-connection-conf-list.xml
# D	beeline/src/test/resources/test-hs2-connection-config-noauth.xml
# D	beeline/src/test/resources/test-hs2-connection-multi-conf-list.xml
# D	beeline/src/test/resources/test-hs2-connection-zookeeper-config.xml
# M	bin/beeline
# M	bin/ext/beeline.sh
# D	bin/ext/cleardanglingscratchdir.sh
# M	bin/ext/cli.sh
# M	bin/ext/debug.sh
# D	bin/ext/fixacidkeyindex.sh
# M	bin/ext/help.sh
# M	bin/ext/hiveserver2.sh
# M	bin/ext/hplsql.sh
# M	bin/ext/lineage.sh
# M	bin/ext/llap.sh
# D	bin/ext/llapdump.sh
# D	bin/ext/llapstatus.sh
# M	bin/ext/metastore.sh
# M	bin/ext/metatool.sh
# M	bin/ext/orcfiledump.sh
# D	bin/ext/replMigration.sh
# M	bin/ext/schemaTool.sh
# D	bin/ext/strictmanagedmigration.sh
# D	bin/ext/tokentool.sh
# M	bin/ext/version.sh
# M	bin/hive
# M	bin/hive-config.sh
# M	bin/hplsql
# D	bin/replstats.sh
# M	checkstyle/asf.header
# M	checkstyle/checkstyle.xml
# M	cli/pom.xml
# M	cli/src/java/org/apache/hadoop/hive/cli/CliDriver.java
# M	cli/src/java/org/apache/hadoop/hive/cli/CliSessionState.java
# M	cli/src/java/org/apache/hadoop/hive/cli/OptionsProcessor.java
# M	cli/src/java/org/apache/hadoop/hive/cli/RCFileCat.java
# M	cli/src/test/org/apache/hadoop/hive/cli/TestCliDriverMethods.java
# M	cli/src/test/org/apache/hadoop/hive/cli/TestCliSessionState.java
# M	cli/src/test/org/apache/hadoop/hive/cli/TestOptionsProcessor.java
# M	cli/src/test/org/apache/hadoop/hive/cli/TestRCFileCat.java
# M	common/pom.xml
# M	common/src/java/org/apache/hadoop/hive/ant/GenHiveTemplate.java
# D	common/src/java/org/apache/hadoop/hive/common/BlobStorageUtils.java
# M	common/src/java/org/apache/hadoop/hive/common/CompressionUtils.java
# D	common/src/java/org/apache/hadoop/hive/common/CopyOnFirstWriteProperties.java
# D	common/src/java/org/apache/hadoop/hive/common/DataCopyStatistics.java
# M	common/src/java/org/apache/hadoop/hive/common/FileUtils.java
# D	common/src/java/org/apache/hadoop/hive/common/GcTimeMonitor.java
# D	common/src/java/org/apache/hadoop/hive/common/HeapMemoryMonitor.java
# M	common/src/java/org/apache/hadoop/hive/common/HiveInterruptCallback.java
# M	common/src/java/org/apache/hadoop/hive/common/HiveInterruptUtils.java
# M	common/src/java/org/apache/hadoop/hive/common/HiveStatsUtils.java
# M	common/src/java/org/apache/hadoop/hive/common/JavaUtils.java
# D	common/src/java/org/apache/hadoop/hive/common/JvmMetrics.java
# D	common/src/java/org/apache/hadoop/hive/common/JvmMetricsInfo.java
# M	common/src/java/org/apache/hadoop/hive/common/JvmPauseMonitor.java
# M	common/src/java/org/apache/hadoop/hive/common/LogUtils.java
# D	common/src/java/org/apache/hadoop/hive/common/MemoryEstimate.java
# D	common/src/java/org/apache/hadoop/hive/common/NumberUtils.java
# D	common/src/java/org/apache/hadoop/hive/common/OTELJavaMetrics.java
# M	common/src/java/org/apache/hadoop/hive/common/ServerUtils.java
# D	common/src/java/org/apache/hadoop/hive/common/StringInternUtils.java
# M	common/src/java/org/apache/hadoop/hive/common/cli/CommonCliOptions.java
# D	common/src/java/org/apache/hadoop/hive/common/cli/EscapeCRLFHelper.java
# M	common/src/java/org/apache/hadoop/hive/common/cli/HiveFileProcessor.java
# M	common/src/java/org/apache/hadoop/hive/common/cli/IHiveFileProcessor.java
# M	common/src/java/org/apache/hadoop/hive/common/cli/ShellCmdExecutor.java
# M	common/src/java/org/apache/hadoop/hive/common/io/CachingPrintStream.java
# M	common/src/java/org/apache/hadoop/hive/common/io/DigestPrintStream.java
# M	common/src/java/org/apache/hadoop/hive/common/io/FetchConverter.java
# M	common/src/java/org/apache/hadoop/hive/common/io/NonSyncByteArrayInputStream.java
# M	common/src/java/org/apache/hadoop/hive/common/io/NonSyncByteArrayOutputStream.java
# D	common/src/java/org/apache/hadoop/hive/common/io/SessionStream.java
# M	common/src/java/org/apache/hadoop/hive/common/io/SortAndDigestPrintStream.java
# M	common/src/java/org/apache/hadoop/hive/common/io/SortPrintStream.java
# D	common/src/java/org/apache/hadoop/hive/common/jsonexplain/Connection.java
# D	common/src/java/org/apache/hadoop/hive/common/jsonexplain/DagJsonParser.java
# D	common/src/java/org/apache/hadoop/hive/common/jsonexplain/DagJsonParserUtils.java
# M	common/src/java/org/apache/hadoop/hive/common/jsonexplain/JsonParser.java
# M	common/src/java/org/apache/hadoop/hive/common/jsonexplain/JsonParserFactory.java
# D	common/src/java/org/apache/hadoop/hive/common/jsonexplain/Op.java
# D	common/src/java/org/apache/hadoop/hive/common/jsonexplain/Printer.java
# D	common/src/java/org/apache/hadoop/hive/common/jsonexplain/Stage.java
# D	common/src/java/org/apache/hadoop/hive/common/jsonexplain/Vertex.java
# M	common/src/java/org/apache/hadoop/hive/common/jsonexplain/tez/TezJsonParser.java
# D	common/src/java/org/apache/hadoop/hive/common/type/Date.java
# M	common/src/java/org/apache/hadoop/hive/common/type/Decimal128.java
# M	common/src/java/org/apache/hadoop/hive/common/type/HiveBaseChar.java
# M	common/src/java/org/apache/hadoop/hive/common/type/HiveChar.java
# M	common/src/java/org/apache/hadoop/hive/common/type/HiveIntervalYearMonth.java
# M	common/src/java/org/apache/hadoop/hive/common/type/HiveVarchar.java
# M	common/src/java/org/apache/hadoop/hive/common/type/SignedInt128.java
# M	common/src/java/org/apache/hadoop/hive/common/type/SqlMathUtil.java
# D	common/src/java/org/apache/hadoop/hive/common/type/Timestamp.java
# D	common/src/java/org/apache/hadoop/hive/common/type/TimestampTZ.java
# D	common/src/java/org/apache/hadoop/hive/common/type/TimestampTZUtil.java
# D	common/src/java/org/apache/hadoop/hive/common/type/TimestampUtils.java
# M	common/src/java/org/apache/hadoop/hive/common/type/UnsignedInt128.java
# D	common/src/java/org/apache/hadoop/hive/conf/Constants.java
# M	common/src/java/org/apache/hadoop/hive/conf/HiveConf.java
# M	common/src/java/org/apache/hadoop/hive/conf/HiveConfUtil.java
# D	common/src/java/org/apache/hadoop/hive/conf/HiveServer2TransportMode.java
# M	common/src/java/org/apache/hadoop/hive/conf/HiveVariableSource.java
# M	common/src/java/org/apache/hadoop/hive/conf/LoopingByteArrayInputStream.java
# M	common/src/java/org/apache/hadoop/hive/conf/SystemVariables.java
# M	common/src/java/org/apache/hadoop/hive/conf/Validator.java
# M	common/src/java/org/apache/hadoop/hive/conf/VariableSubstitution.java
# D	common/src/java/org/apache/hadoop/hive/ql/ErrorMsg.java
# M	common/src/java/org/apache/hadoop/hive/ql/log/PerfLogger.java
# M	common/src/java/org/apache/hive/common/HiveCompat.java
# M	common/src/java/org/apache/hive/common/HiveVersionAnnotation.java
# D	common/src/java/org/apache/hive/common/util/ACLConfigurationParser.java
# M	common/src/java/org/apache/hive/common/util/AnnotationUtils.java
# D	common/src/java/org/apache/hive/common/util/CleanerUtil.java
# D	common/src/java/org/apache/hive/common/util/DateParser.java
# M	common/src/java/org/apache/hive/common/util/DateUtils.java
# M	common/src/java/org/apache/hive/common/util/Decimal128FastBuffer.java
# M	common/src/java/org/apache/hive/common/util/FixedSizedObjectPool.java
# M	common/src/java/org/apache/hive/common/util/HashCodeUtil.java
# M	common/src/java/org/apache/hive/common/util/HiveStringUtils.java
# M	common/src/java/org/apache/hive/common/util/HiveTestUtils.java
# M	common/src/java/org/apache/hive/common/util/HiveVersionInfo.java
# D	common/src/java/org/apache/hive/common/util/ProcessUtils.java
# D	common/src/java/org/apache/hive/common/util/Ref.java
# M	common/src/java/org/apache/hive/common/util/ReflectionUtil.java
# D	common/src/java/org/apache/hive/common/util/RetryUtilities.java
# M	common/src/java/org/apache/hive/common/util/ShutdownHookManager.java
# M	common/src/java/org/apache/hive/common/util/StreamPrinter.java
# D	common/src/java/org/apache/hive/common/util/SuppressFBWarnings.java
# M	common/src/java/org/apache/hive/common/util/TimestampParser.java
# M	common/src/java/org/apache/hive/http/AdminAuthorizedServlet.java
# M	common/src/java/org/apache/hive/http/ConfServlet.java
# M	common/src/java/org/apache/hive/http/HttpServer.java
# M	common/src/java/org/apache/hive/http/JMXJsonServlet.java
# D	common/src/java/org/apache/hive/http/Log4j2ConfiguratorServlet.java
# D	common/src/java/org/apache/hive/http/ProfileOutputServlet.java
# D	common/src/java/org/apache/hive/http/ProfileServlet.java
# M	common/src/java/org/apache/hive/http/StackServlet.java
# M	common/src/main/resources/hive-log4j2.properties
# D	common/src/main/resources/parquet-logging.properties
# D	common/src/test/org/apache/hadoop/hive/common/TestBlobStorageUtils.java
# D	common/src/test/org/apache/hadoop/hive/common/TestFileUtils.java
# D	common/src/test/org/apache/hadoop/hive/common/TestLogUtils.java
# D	common/src/test/org/apache/hadoop/hive/common/TestNumberUtils.java
# D	common/src/test/org/apache/hadoop/hive/common/TestTezJsonParser.java
# D	common/src/test/org/apache/hadoop/hive/common/type/HiveDecimalTestBase.java
# M	common/src/test/org/apache/hadoop/hive/common/type/TestDecimal128.java
# M	common/src/test/org/apache/hadoop/hive/common/type/TestHiveBaseChar.java
# M	common/src/test/org/apache/hadoop/hive/common/type/TestHiveChar.java
# D	common/src/test/org/apache/hadoop/hive/common/type/TestHiveDecimalOrcSerializationUtils.java
# M	common/src/test/org/apache/hadoop/hive/common/type/TestHiveIntervalDayTime.java
# M	common/src/test/org/apache/hadoop/hive/common/type/TestHiveIntervalYearMonth.java
# M	common/src/test/org/apache/hadoop/hive/common/type/TestHiveVarchar.java
# M	common/src/test/org/apache/hadoop/hive/common/type/TestSignedInt128.java
# M	common/src/test/org/apache/hadoop/hive/common/type/TestSqlMathUtil.java
# D	common/src/test/org/apache/hadoop/hive/common/type/TestTimestampTZ.java
# M	common/src/test/org/apache/hadoop/hive/common/type/TestUnsignedInt128.java
# D	common/src/test/org/apache/hadoop/hive/conf/HiveConfForTest.java
# D	common/src/test/org/apache/hadoop/hive/conf/TestHiveAsyncLogging.java
# M	common/src/test/org/apache/hadoop/hive/conf/TestHiveConf.java
# M	common/src/test/org/apache/hadoop/hive/conf/TestHiveConfRestrictList.java
# D	common/src/test/org/apache/hadoop/hive/conf/TestHiveConfUtil.java
# D	common/src/test/org/apache/hadoop/hive/conf/TestHiveConfVarsValidate.java
# M	common/src/test/org/apache/hadoop/hive/conf/TestHiveLogging.java
# D	common/src/test/org/apache/hadoop/hive/conf/TestSystemVariables.java
# M	common/src/test/org/apache/hadoop/hive/conf/TestVariableSubstitution.java
# D	common/src/test/org/apache/hive/common/util/MockFileSystem.java
# D	common/src/test/org/apache/hive/common/util/Retry.java
# D	common/src/test/org/apache/hive/common/util/RetryTestRunner.java
# D	common/src/test/org/apache/hive/common/util/TestACLConfigurationParser.java
# D	common/src/test/org/apache/hive/common/util/TestDateParser.java
# M	common/src/test/org/apache/hive/common/util/TestFixedSizedObjectPool.java
# M	common/src/test/org/apache/hive/common/util/TestHiveStringUtils.java
# D	common/src/test/org/apache/hive/common/util/TestRetryUtilities.java
# M	common/src/test/org/apache/hive/common/util/TestShutdownHookManager.java
# M	common/src/test/org/apache/hive/common/util/TestTimestampParser.java
# M	common/src/test/resources/hive-exec-log4j2-test.properties
# M	common/src/test/resources/hive-log4j2-test.properties
# M	conf/hive-env.sh.template
# M	conf/hive-site.xml
# M	conf/ivysettings.xml
# M	contrib/pom.xml
# M	contrib/src/java/org/apache/hadoop/hive/contrib/fileformat/base64/Base64TextInputFormat.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/fileformat/base64/Base64TextOutputFormat.java
# D	contrib/src/java/org/apache/hadoop/hive/contrib/genericudf/example/GenericUDFAdd10.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/genericudf/example/GenericUDFDBOutput.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/metastore/hooks/SampleURLHook.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/mr/GenericMR.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/mr/Mapper.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/mr/Output.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/mr/Reducer.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/mr/example/IdentityMapper.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/mr/example/WordCountReduce.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/serde2/RegexSerDe.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/serde2/TypedBytesSerDe.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/serde2/s3/S3LogDeserializer.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/serde2/s3/S3LogStruct.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/udaf/example/UDAFExampleAvg.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/udaf/example/UDAFExampleGroupConcat.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/udaf/example/UDAFExampleMax.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/udaf/example/UDAFExampleMaxMinNUtil.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/udaf/example/UDAFExampleMaxN.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/udaf/example/UDAFExampleMin.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/udaf/example/UDAFExampleMinN.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/udf/UDFRowSequence.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/udf/example/UDFExampleAdd.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/udf/example/UDFExampleArraySum.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/udf/example/UDFExampleFormat.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/udf/example/UDFExampleMapConcat.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/udf/example/UDFExampleStructPrint.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/udtf/example/GenericUDTFCount2.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/udtf/example/GenericUDTFExplode2.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/util/typedbytes/Type.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/util/typedbytes/TypedBytesInput.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/util/typedbytes/TypedBytesOutput.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/util/typedbytes/TypedBytesRecordInput.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/util/typedbytes/TypedBytesRecordOutput.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/util/typedbytes/TypedBytesRecordReader.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/util/typedbytes/TypedBytesRecordWriter.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/util/typedbytes/TypedBytesWritable.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/util/typedbytes/TypedBytesWritableInput.java
# M	contrib/src/java/org/apache/hadoop/hive/contrib/util/typedbytes/TypedBytesWritableOutput.java
# M	contrib/src/test/org/apache/hadoop/hive/contrib/mr/TestGenericMR.java
# M	contrib/src/test/org/apache/hadoop/hive/contrib/serde2/TestRegexSerDe.java
# M	contrib/src/test/queries/clientnegative/case_with_row_sequence.q
# M	contrib/src/test/queries/clientnegative/invalid_row_sequence.q
# M	contrib/src/test/queries/clientnegative/serde_regex.q
# M	contrib/src/test/queries/clientnegative/udtf_explode2.q
# M	contrib/src/test/queries/clientpositive/dboutput.q
# M	contrib/src/test/queries/clientpositive/fileformat_base64.q
# M	contrib/src/test/queries/clientpositive/java_mr_example.q
# M	contrib/src/test/queries/clientpositive/lateral_view_explode2.q
# M	contrib/src/test/queries/clientpositive/serde_regex.q
# M	contrib/src/test/queries/clientpositive/serde_typedbytes.q
# M	contrib/src/test/queries/clientpositive/serde_typedbytes2.q
# M	contrib/src/test/queries/clientpositive/serde_typedbytes3.q
# M	contrib/src/test/queries/clientpositive/serde_typedbytes4.q
# M	contrib/src/test/queries/clientpositive/serde_typedbytes5.q
# M	contrib/src/test/queries/clientpositive/serde_typedbytes_null.q
# M	contrib/src/test/queries/clientpositive/udaf_example_avg.q
# M	contrib/src/test/queries/clientpositive/udaf_example_group_concat.q
# M	contrib/src/test/queries/clientpositive/udaf_example_max.q
# M	contrib/src/test/queries/clientpositive/udaf_example_max_n.q
# M	contrib/src/test/queries/clientpositive/udaf_example_min.q
# M	contrib/src/test/queries/clientpositive/udaf_example_min_n.q
# M	contrib/src/test/queries/clientpositive/udf_example_add.q
# M	contrib/src/test/queries/clientpositive/udf_example_arraymapstruct.q
# M	contrib/src/test/queries/clientpositive/udf_example_format.q
# M	contrib/src/test/queries/clientpositive/udf_row_sequence.q
# M	contrib/src/test/queries/clientpositive/udtf_explode2.q
# M	contrib/src/test/queries/clientpositive/udtf_output_on_close.q
# M	contrib/src/test/queries/clientpositive/url_hook.q
# D	contrib/src/test/queries/clientpositive/vector_udf_example_arraymapstruct.q
# M	contrib/src/test/results/clientnegative/case_with_row_sequence.q.out
# M	contrib/src/test/results/clientnegative/invalid_row_sequence.q.out
# M	contrib/src/test/results/clientnegative/serde_regex.q.out
# M	contrib/src/test/results/clientpositive/dboutput.q.out
# M	contrib/src/test/results/clientpositive/fileformat_base64.q.out
# M	contrib/src/test/results/clientpositive/serde_regex.q.out
# M	contrib/src/test/results/clientpositive/serde_s3.q.out
# M	contrib/src/test/results/clientpositive/serde_typedbytes.q.out
# M	contrib/src/test/results/clientpositive/serde_typedbytes2.q.out
# M	contrib/src/test/results/clientpositive/serde_typedbytes3.q.out
# M	contrib/src/test/results/clientpositive/serde_typedbytes4.q.out
# M	contrib/src/test/results/clientpositive/serde_typedbytes5.q.out
# M	contrib/src/test/results/clientpositive/serde_typedbytes6.q.out
# M	contrib/src/test/results/clientpositive/serde_typedbytes_null.q.out
# M	contrib/src/test/results/clientpositive/udaf_example_avg.q.out
# M	contrib/src/test/results/clientpositive/udaf_example_group_concat.q.out
# M	contrib/src/test/results/clientpositive/udaf_example_max.q.out
# M	contrib/src/test/results/clientpositive/udaf_example_max_n.q.out
# M	contrib/src/test/results/clientpositive/udaf_example_min.q.out
# M	contrib/src/test/results/clientpositive/udaf_example_min_n.q.out
# M	contrib/src/test/results/clientpositive/udf_example_add.q.out
# M	contrib/src/test/results/clientpositive/udf_example_arraymapstruct.q.out
# M	contrib/src/test/results/clientpositive/udf_example_format.q.out
# M	contrib/src/test/results/clientpositive/udf_row_sequence.q.out
# M	contrib/src/test/results/clientpositive/url_hook.q.out
# D	contrib/src/test/results/clientpositive/vector_udf_example_arraymapstruct.q.out
# M	data/conf/fair-scheduler-test.xml
# M	data/conf/hive-log4j2.properties
# M	data/conf/hive-site-old.xml
# M	data/conf/hive-site.xml
# M	data/conf/hivemetastore-site.xml
# M	data/conf/llap/hive-site.xml
# D	data/conf/llap/hivemetastore-site.xml
# M	data/conf/llap/tez-site.xml
# M	data/conf/tez/hive-site.xml
# M	data/conf/tez/tez-site.xml
# D	data/files/2048.csv
# D	data/files/3col_data.txt
# D	data/files/4col_data.txt
# D	data/files/5col_data.txt
# M	data/files/alltypesorc
# D	data/files/alltypesorc3xcols
# D	data/files/alltypesorc_voriginal
# D	data/files/alltypesorcold
# M	data/files/avro_date.txt
# D	data/files/avro_historical_timestamp_legacy.avro
# D	data/files/avro_historical_timestamp_new.avro
# D	data/files/avro_legacy_mixed_dates.avro
# D	data/files/avro_legacy_mixed_timestamps.avro
# M	data/files/avro_timestamp.txt
# D	data/files/birthdays
# D	data/files/compressed_4line_file1.csv
# D	data/files/compressed_4line_file2.csv
# D	data/files/compressed_4line_file2.csv.bz2
# D	data/files/control_characters.txt
# D	data/files/customer_demographics.txt
# D	data/files/data_including_invalid_values.parquet
# D	data/files/data_with_union.txt
# D	data/files/data_with_valid_values.parquet
# M	data/files/datatypes.txt
# D	data/files/dec_old.avro
# M	data/files/decimal.txt
# D	data/files/decimal64table.csv
# D	data/files/decimal64table1.csv
# D	data/files/decimal64table2.csv
# D	data/files/e011_01.txt
# D	data/files/employee_hive_3_1_3_us_pacific.parquet
# D	data/files/empty_array.txt
# D	data/files/emptyhead_4line_file1.csv
# D	data/files/emptyhead_4line_file1.csv.bz2
# D	data/files/engesc8151.txt
# D	data/files/escape_crlf.parquet
# M	data/files/escapetest.txt
# D	data/files/esource.txt
# D	data/files/events.txt
# M	data/files/exported_table/_metadata
# D	data/files/fullouter_long_big_1a.txt
# D	data/files/fullouter_long_big_1a_nonull.txt
# D	data/files/fullouter_long_big_1b.txt
# D	data/files/fullouter_long_big_1c.txt
# D	data/files/fullouter_long_big_1d.txt
# D	data/files/fullouter_long_small_1a.txt
# D	data/files/fullouter_long_small_1a_nonull.txt
# D	data/files/fullouter_long_small_1b.txt
# D	data/files/fullouter_long_small_1c.txt
# D	data/files/fullouter_long_small_1d.txt
# D	data/files/fullouter_multikey_big_1a.txt
# D	data/files/fullouter_multikey_big_1a_nonull.txt
# D	data/files/fullouter_multikey_big_1b.txt
# D	data/files/fullouter_multikey_small_1a.txt
# D	data/files/fullouter_multikey_small_1a_nonull.txt
# D	data/files/fullouter_multikey_small_1b.txt
# D	data/files/fullouter_string_big_1a.txt
# D	data/files/fullouter_string_big_1a_nonull.txt
# D	data/files/fullouter_string_small_1a.txt
# D	data/files/fullouter_string_small_1a_nonull.txt
# D	data/files/geo-json.json
# D	data/files/grad2.avsc
# D	data/files/having_data.txt
# D	data/files/hive22670.parquet
# D	data/files/hive_26612.parquet
# D	data/files/integer_sequence.txt
# D	data/files/jsonserde.txt
# M	data/files/keystore.jks
# D	data/files/keystore_exampledotcom.jks
# D	data/files/legacyLeapYearInSingaporeTZ
# D	data/files/nested_sample_1.json
# D	data/files/nested_sample_2.json
# D	data/files/nested_ts.avsc
# M	data/files/opencsv-data.txt
# D	data/files/orc_compressed
# D	data/files/orc_legacy_mixed_dates.orc
# D	data/files/orc_legacy_mixed_timestamps.orc
# M	data/files/orc_split_elim.orc
# D	data/files/orc_test_ppd
# D	data/files/orc_uncompressed
# D	data/files/over10k.gz
# D	data/files/over4_null
# D	data/files/parquet_complex_types.txt
# D	data/files/parquet_create_people.txt
# D	data/files/parquet_historical_timestamp_legacy.parq
# D	data/files/parquet_historical_timestamp_new.parq
# D	data/files/parquet_int_decimal_1.parquet
# D	data/files/parquet_int_decimal_2.parquet
# D	data/files/parquet_legacy_mixed_dates.parq
# D	data/files/parquet_legacy_mixed_timestamps.parq
# D	data/files/parquet_non_dictionary_types.txt
# M	data/files/parquet_type_promotion.txt
# D	data/files/parquet_vector_map_type.txt
# D	data/files/part.orc
# D	data/files/part.parquet
# D	data/files/part_data_explain_ddl.csv
# D	data/files/part_tiny_nulls.txt
# D	data/files/query-hive-28087.csv
# D	data/files/regex-path-2015-12-10_03.txt
# D	data/files/regex-path-201512-10_03.txt
# D	data/files/regex-path-2015121003.txt
# D	data/files/rfc5424-hs2-2.log
# D	data/files/rfc5424-hs2-exception.log
# D	data/files/rfc5424-hs2.log
# D	data/files/single_int.txt
# D	data/files/small_csv.csv
# D	data/files/smbdata.txt
# D	data/files/starships.sql
# D	data/files/struct_type.txt
# D	data/files/student_10_lines
# D	data/files/studentnull100
# D	data/files/students.txt
# D	data/files/studenttab10k
# D	data/files/symlink-with-regex.txt
# D	data/files/t11_csv_serde.csv
# D	data/files/t1_multi_delimit.csv
# D	data/files/t2_multi_delimit.csv
# D	data/files/t3_multi_delimit.csv
# D	data/files/t4_multi_delimit.csv
# D	data/files/table1.avsc
# D	data/files/table1_1.avsc
# D	data/files/table1_delim.txt
# D	data/files/table_19.dat
# D	data/files/table_8.dat
# D	data/files/test.csv.gz
# D	data/files/test.jceks
# D	data/files/test_data
# D	data/files/test_dec_space.csv
# D	data/files/test_null_array.csv
# D	data/files/test_sp_chars_decimal.csv
# D	data/files/test_timestamp.csv
# D	data/files/test_uint.parquet
# D	data/files/timestamps.txt
# D	data/files/timestamps_mixed_formats.txt
# D	data/files/tjoin3.txt
# D	data/files/tjoin4.txt
# D	data/files/trunc_number.txt
# D	data/files/trunc_number1.txt
# M	data/files/truststore.jks
# D	data/files/union_non_nullable.txt
# D	data/files/union_nullable.txt
# D	data/files/unique_1.txt
# D	data/files/unique_2.txt
# D	data/files/vector_groupingsets_switchmode.csv
# D	data/files/vector_ptf_part_simple.txt
# D	data/files/vector_ptf_part_simple_all_datatypes.txt
# D	data/files/web_sales.parquet
# D	data/files/windowing_distinct.txt
# M	data/scripts/input20_script.py
# D	data/scripts/kafka_init_data.csv
# D	data/scripts/kafka_init_data.json
# D	data/scripts/q_test_author_book_tables.sql
# D	data/scripts/q_test_author_table.sql
# D	data/scripts/q_test_book_table.sql
# D	data/scripts/q_test_city_table.sql
# M	data/scripts/q_test_cleanup.sql
# D	data/scripts/q_test_cleanup_compare.sql
# D	data/scripts/q_test_cleanup_contrib.sql
# D	data/scripts/q_test_cleanup_druid.sql
# D	data/scripts/q_test_cleanup_src.sql
# D	data/scripts/q_test_cleanup_tez.sql
# D	data/scripts/q_test_country_state_city_tables.sql
# D	data/scripts/q_test_country_table.sql
# D	data/scripts/q_test_country_table_with_schema.mariadb.sql
# D	data/scripts/q_test_country_table_with_schema.mssql.sql
# D	data/scripts/q_test_country_table_with_schema.oracle.sql
# D	data/scripts/q_test_country_table_with_schema.postgres.sql
# D	data/scripts/q_test_druid_init.sql
# M	data/scripts/q_test_init.sql
# D	data/scripts/q_test_init_compare.sql
# D	data/scripts/q_test_init_contrib.sql
# D	data/scripts/q_test_init_for_minimr.sql
# D	data/scripts/q_test_init_parse.sql
# D	data/scripts/q_test_init_src.sql
# D	data/scripts/q_test_init_src_with_stats.sql
# D	data/scripts/q_test_init_tez.sql
# D	data/scripts/q_test_state_table.sql
# D	data/scripts/sleep.py
# M	dev-support/eclipse-styles.xml
# D	dev-support/hive-personality.sh
# D	dev-support/nightly
# D	dev-support/smart-apply-patch.sh
# D	dev-support/test-patch.sh
# D	dev-support/yetus-wrapper.sh
# M	errata.txt
# D	hbase-handler/README.md
# M	hbase-handler/pom.xml
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/AbstractHBaseKeyFactory.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/AbstractHBaseKeyPredicateDecomposer.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/ColumnMappings.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/CompositeHBaseKeyFactory.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/DataInputInputStream.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/DataOutputOutputStream.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/DefaultHBaseKeyFactory.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/HBaseCompositeKey.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/HBaseKeyFactory.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/HBaseLazyObjectFactory.java
# D	hbase-handler/src/java/org/apache/hadoop/hive/hbase/HBaseMetaHook.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/HBaseRowSerializer.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/HBaseScanRange.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/HBaseSerDe.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/HBaseSerDeHelper.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/HBaseSerDeParameters.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/HBaseSplit.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/HBaseStorageHandler.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/HBaseTableSnapshotInputFormatUtil.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/HiveHBaseInputFormatUtil.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/HiveHBaseTableInputFormat.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/HiveHBaseTableOutputFormat.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/HiveHBaseTableSnapshotInputFormat.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/HiveHFileOutputFormat.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/LazyHBaseCellMap.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/LazyHBaseRow.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/PutWritable.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/ResultWritable.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/package-info.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/struct/AvroHBaseValueFactory.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/struct/DefaultHBaseValueFactory.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/struct/HBaseStructValue.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/struct/HBaseValueFactory.java
# M	hbase-handler/src/java/org/apache/hadoop/hive/hbase/struct/StructHBaseValueFactory.java
# M	hbase-handler/src/test/org/apache/hadoop/hive/hbase/HBaseTestAvroSchemaRetriever.java
# M	hbase-handler/src/test/org/apache/hadoop/hive/hbase/HBaseTestCompositeKey.java
# M	hbase-handler/src/test/org/apache/hadoop/hive/hbase/HBaseTestStructSerializer.java
# M	hbase-handler/src/test/org/apache/hadoop/hive/hbase/SampleHBaseKeyFactory.java
# M	hbase-handler/src/test/org/apache/hadoop/hive/hbase/SampleHBaseKeyFactory2.java
# M	hbase-handler/src/test/org/apache/hadoop/hive/hbase/SampleHBaseKeyFactory3.java
# D	hbase-handler/src/test/org/apache/hadoop/hive/hbase/TestHBaseQueries.java
# M	hbase-handler/src/test/org/apache/hadoop/hive/hbase/TestHBaseSerDe.java
# D	hbase-handler/src/test/org/apache/hadoop/hive/hbase/TestHBaseStorageHandler.java
# D	hbase-handler/src/test/org/apache/hadoop/hive/hbase/TestHiveHBaseTableOutputFormat.java
# D	hbase-handler/src/test/org/apache/hadoop/hive/hbase/TestLazyHBaseCellMap.java
# M	hbase-handler/src/test/org/apache/hadoop/hive/hbase/TestLazyHBaseObject.java
# M	hbase-handler/src/test/org/apache/hadoop/hive/hbase/TestPutResultWritable.java
# M	hbase-handler/src/test/org/apache/hadoop/hive/hbase/avro/Address.java
# M	hbase-handler/src/test/org/apache/hadoop/hive/hbase/avro/ContactInfo.java
# M	hbase-handler/src/test/org/apache/hadoop/hive/hbase/avro/Employee.java
# M	hbase-handler/src/test/org/apache/hadoop/hive/hbase/avro/HomePhone.java
# M	hbase-handler/src/test/org/apache/hadoop/hive/hbase/avro/OfficePhone.java
# M	hbase-handler/src/test/queries/negative/cascade_dbdrop.q
# D	hbase-handler/src/test/queries/negative/create_table_stored_by_stored_as_failure.q
# M	hbase-handler/src/test/queries/negative/generatehfiles_require_family_path.q
# D	hbase-handler/src/test/queries/negative/hbase_ddl.q
# D	hbase-handler/src/test/queries/positive/drop_database_table_hooks.q
# M	hbase-handler/src/test/queries/positive/external_table_ppd.q
# D	hbase-handler/src/test/queries/positive/hbase_avro_nested_timestamp.q
# D	hbase-handler/src/test/queries/positive/hbase_between_pushdown.q
# M	hbase-handler/src/test/queries/positive/hbase_binary_binary.q
# M	hbase-handler/src/test/queries/positive/hbase_binary_map_queries.q
# M	hbase-handler/src/test/queries/positive/hbase_binary_map_queries_prefix.q
# M	hbase-handler/src/test/queries/positive/hbase_binary_storage_queries.q
# D	hbase-handler/src/test/queries/positive/hbase_bulk.q
# M	hbase-handler/src/test/queries/positive/hbase_custom_key.q
# M	hbase-handler/src/test/queries/positive/hbase_custom_key2.q
# M	hbase-handler/src/test/queries/positive/hbase_custom_key3.q
# D	hbase-handler/src/test/queries/positive/hbase_ddl.q
# D	hbase-handler/src/test/queries/positive/hbase_decimal_decimal.q
# D	hbase-handler/src/test/queries/positive/hbase_disable_limitopt.q
# M	hbase-handler/src/test/queries/positive/hbase_handler_bulk.q
# M	hbase-handler/src/test/queries/positive/hbase_handler_snapshot.q
# M	hbase-handler/src/test/queries/positive/hbase_joins.q
# M	hbase-handler/src/test/queries/positive/hbase_null_first_col.q
# D	hbase-handler/src/test/queries/positive/hbase_ppd_boolean_cols.q
# M	hbase-handler/src/test/queries/positive/hbase_ppd_join.q
# M	hbase-handler/src/test/queries/positive/hbase_ppd_key_range.q
# M	hbase-handler/src/test/queries/positive/hbase_pushdown.q
# M	hbase-handler/src/test/queries/positive/hbase_queries.q
# M	hbase-handler/src/test/queries/positive/hbase_scan_params.q
# M	hbase-handler/src/test/queries/positive/hbase_single_sourced_multi_insert.q
# M	hbase-handler/src/test/queries/positive/hbase_timestamp.q
# M	hbase-handler/src/test/queries/positive/hbase_timestamp_format.q
# D	hbase-handler/src/test/queries/positive/hbase_viewjoins.q
# D	hbase-handler/src/test/queries/positive/hbasestats.q
# M	hbase-handler/src/test/queries/positive/ppd_key_ranges.q
# M	hbase-handler/src/test/results/negative/cascade_dbdrop.q.out
# D	hbase-handler/src/test/results/negative/create_table_stored_by_stored_as_failure.q.out
# M	hbase-handler/src/test/results/negative/generatehfiles_require_family_path.q.out
# D	hbase-handler/src/test/results/negative/hbase_ddl.q.out
# D	hbase-handler/src/test/results/positive/drop_database_table_hooks.q.out
# M	hbase-handler/src/test/results/positive/external_table_ppd.q.out
# D	hbase-handler/src/test/results/positive/hbase_avro_nested_timestamp.q.out
# D	hbase-handler/src/test/results/positive/hbase_between_pushdown.q.out
# M	hbase-handler/src/test/results/positive/hbase_binary_binary.q.out
# M	hbase-handler/src/test/results/positive/hbase_binary_external_table_queries.q.out
# M	hbase-handler/src/test/results/positive/hbase_binary_map_queries.q.out
# M	hbase-handler/src/test/results/positive/hbase_binary_map_queries_prefix.q.out
# M	hbase-handler/src/test/results/positive/hbase_binary_storage_queries.q.out
# D	hbase-handler/src/test/results/positive/hbase_bulk.q.out
# M	hbase-handler/src/test/results/positive/hbase_custom_key.q.out
# M	hbase-handler/src/test/results/positive/hbase_custom_key2.q.out
# M	hbase-handler/src/test/results/positive/hbase_custom_key3.q.out
# D	hbase-handler/src/test/results/positive/hbase_ddl.q.out
# D	hbase-handler/src/test/results/positive/hbase_decimal_decimal.q.out
# D	hbase-handler/src/test/results/positive/hbase_disable_limitopt.q.out
# M	hbase-handler/src/test/results/positive/hbase_handler_bulk.q.out
# M	hbase-handler/src/test/results/positive/hbase_joins.q.out
# M	hbase-handler/src/test/results/positive/hbase_null_first_col.q.out
# D	hbase-handler/src/test/results/positive/hbase_ppd_boolean_cols.q.out
# M	hbase-handler/src/test/results/positive/hbase_ppd_join.q.out
# M	hbase-handler/src/test/results/positive/hbase_ppd_key_range.q.out
# M	hbase-handler/src/test/results/positive/hbase_pushdown.q.out
# M	hbase-handler/src/test/results/positive/hbase_queries.q.out
# M	hbase-handler/src/test/results/positive/hbase_scan_params.q.out
# M	hbase-handler/src/test/results/positive/hbase_single_sourced_multi_insert.q.out
# M	hbase-handler/src/test/results/positive/hbase_timestamp.q.out
# M	hbase-handler/src/test/results/positive/hbase_timestamp_format.q.out
# D	hbase-handler/src/test/results/positive/hbase_viewjoins.q.out
# D	hbase-handler/src/test/results/positive/hbasestats.q.out
# M	hbase-handler/src/test/results/positive/ppd_key_ranges.q.out
# M	hcatalog/bin/hcat
# M	hcatalog/build.properties
# M	hcatalog/core/pom.xml
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/cli/HCatCli.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/cli/HCatDriver.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/cli/SemanticAnalysis/CreateDatabaseHook.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/cli/SemanticAnalysis/CreateTableHook.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/cli/SemanticAnalysis/HCatAuthUtil.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/cli/SemanticAnalysis/HCatSemanticAnalyzer.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/cli/SemanticAnalysis/HCatSemanticAnalyzerBase.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/common/ErrorType.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/common/HCatConstants.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/common/HCatContext.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/common/HCatException.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/common/HCatUtil.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/common/HiveClientCache.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/DataType.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/DefaultHCatRecord.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/HCatRecord.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/HCatRecordObjectInspector.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/HCatRecordObjectInspectorFactory.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/HCatRecordSerDe.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/HCatRecordable.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/JsonSerDe.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/LazyHCatRecord.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/Pair.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/ReaderWriter.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/schema/HCatFieldSchema.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/schema/HCatSchema.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/schema/HCatSchemaUtils.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/transfer/DataTransferFactory.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/transfer/EntityBase.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/transfer/HCatReader.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/transfer/HCatWriter.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/transfer/ReadEntity.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/transfer/ReaderContext.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/transfer/WriteEntity.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/transfer/WriterContext.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/transfer/impl/HCatInputFormatReader.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/transfer/impl/HCatOutputFormatWriter.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/transfer/impl/ReaderContextImpl.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/transfer/impl/WriterContextImpl.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/transfer/state/DefaultStateProvider.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/data/transfer/state/StateProvider.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/har/HarOutputCommitterPostProcessor.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/mapreduce/DefaultOutputCommitterContainer.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/mapreduce/DefaultOutputFormatContainer.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/mapreduce/DefaultRecordWriterContainer.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/mapreduce/DynamicPartitionFileRecordWriterContainer.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/mapreduce/FileOutputCommitterContainer.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/mapreduce/FileOutputFormatContainer.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/mapreduce/FileRecordWriterContainer.java
# M	hcatalog/core/src/main/java/org/apache/hive/hcatalog/mapreduce/FosterStorageHandler.java
# ...
# Searching for bug ID: HIVE-19632 (Version: 3.1.0)
# Searching for bug ID: HIVE-19629 (Version: 3.1.0)
# Searching for bug ID: HIVE-19614 (Version: 3.1.0)
# Searching for bug ID: HIVE-19613 (Version: 3.1.0)
# Searching for bug ID: HIVE-19588 (Version: 3.1.0)
# Searching for bug ID: HIVE-19575 (Version: 3.1.0)
# Searching for bug ID: HIVE-19568 (Version: 3.1.0)
# Searching for bug ID: HIVE-19567 (Version: 3.1.0)
# Searching for bug ID: HIVE-19485 (Version: 3.1.0)
# Searching for bug ID: HIVE-19468 (Version: 3.1.0)
# Searching for bug ID: HIVE-19389 (Version: 3.1.0)
# Searching for bug ID: HIVE-19385 (Version: 3.1.0)
# Searching for bug ID: HIVE-19315 (Version: 3.1.0)
# Searching for bug ID: HIVE-19277 (Version: 3.1.0)
# Searching for bug ID: HIVE-19249 (Version: 3.1.0)
# Searching for bug ID: HIVE-19199 (Version: 3.1.0)
# Searching for bug ID: HIVE-19168 (Version: 3.1.0)
# Searching for bug ID: HIVE-18874 (Version: 3.1.0)
# Searching for bug ID: HIVE-26209 (Version: 2.3.6)
# Searching for bug ID: HIVE-23086 (Version: 2.3.6)
# Searching for bug ID: HIVE-22967 (Version: 3.1.2)
# Searching for bug ID: HIVE-22670 (Version: 3.1.2)
# Searching for bug ID: HIVE-22480 (Version: 2.3.6)
# Searching for bug ID: HIVE-22453 (Version: 3.1.2)
# Searching for bug ID: HIVE-22268 (Version: 3.1.2)
# Searching for bug ID: HIVE-22190 (Version: 3.1.2)
# Searching for bug ID: HIVE-20628 (Version: 2.1.0)
# Searching for bug ID: HIVE-20080 (Version: 2.1.0)
# Searching for bug ID: HIVE-19860 (Version: 2.1.0)
# Searching for bug ID: HIVE-19743 (Version: 2.1.0)
# Searching for bug ID: HIVE-19250 (Version: 2.1.0)
# Searching for bug ID: HIVE-19231 (Version: 2.1.0)
# Searching for bug ID: HIVE-19230 (Version: 2.1.0)
# Searching for bug ID: HIVE-18572 (Version: 2.1.0)
# Searching for bug ID: HIVE-18459 (Version: 2.1.0)
# Searching for bug ID: HIVE-17829 (Version: 2.1.0)
# Searching for bug ID: HIVE-17279 (Version: 2.1.0)
# Searching for bug ID: HIVE-16421 (Version: 2.1.0)
# Searching for bug ID: HIVE-16287 (Version: 2.1.0)
# Searching for bug ID: HIVE-16274 (Version: 2.1.0)
# Searching for bug ID: HIVE-16163 (Version: 2.1.0)
# Searching for bug ID: HIVE-15995 (Version: 2.1.0)
# Searching for bug ID: HIVE-15902 (Version: 2.1.0)
# Searching for bug ID: HIVE-15862 (Version: 2.1.0)
# Searching for bug ID: HIVE-15646 (Version: 2.1.0)
# Searching for bug ID: HIVE-15552 (Version: 2.1.0)
# Searching for bug ID: HIVE-15531 (Version: 2.1.0)
# Searching for bug ID: HIVE-15498 (Version: 2.1.0)
# Searching for bug ID: HIVE-15443 (Version: 2.1.0)
# Searching for bug ID: HIVE-15402 (Version: 2.1.0)
# Searching for bug ID: HIVE-15308 (Version: 2.1.0)
# Searching for bug ID: HIVE-15291 (Version: 2.1.0)
# Searching for bug ID: HIVE-15267 (Version: 2.1.0)
# Searching for bug ID: HIVE-15239 (Version: 2.1.0)
# Searching for bug ID: HIVE-15237 (Version: 2.1.0)
# Searching for bug ID: HIVE-15181 (Version: 2.1.0)
# Searching for bug ID: HIVE-15175 (Version: 2.1.0)
# Searching for bug ID: HIVE-15158 (Version: 2.1.0)
# Searching for bug ID: HIVE-15155 (Version: 2.1.0)
# Searching for bug ID: HIVE-15070 (Version: 2.1.0)
# Searching for bug ID: HIVE-15050 (Version: 2.1.0)
# Searching for bug ID: HIVE-15035 (Version: 2.1.0)
# Searching for bug ID: HIVE-15030 (Version: 2.1.0)
# Searching for bug ID: HIVE-15029 (Version: 2.1.0)
# Searching for bug ID: HIVE-14982 (Version: 2.1.0)
# Searching for bug ID: HIVE-14980 (Version: 2.1.0)
# Searching for bug ID: HIVE-14966 (Version: 2.1.0)
# Searching for bug ID: HIVE-14960 (Version: 2.1.0)
# Searching for bug ID: HIVE-14959 (Version: 2.1.0)
# Searching for bug ID: HIVE-14873 (Version: 2.1.0)
# Searching for bug ID: HIVE-14839 (Version: 2.1.0)
# Searching for bug ID: HIVE-14819 (Version: 2.1.0)
# Searching for bug ID: HIVE-14798 (Version: 2.1.0)
# Searching for bug ID: HIVE-14792 (Version: 2.1.0)
# Searching for bug ID: HIVE-14779 (Version: 2.1.0)
# Searching for bug ID: HIVE-14773 (Version: 2.1.0)
# Searching for bug ID: HIVE-14726 (Version: 2.1.0)
# Searching for bug ID: HIVE-14698 (Version: 2.1.0)
# Searching for bug ID: HIVE-14697 (Version: 2.1.0)
# Searching for bug ID: HIVE-14690 (Version: 2.1.0)
# Searching for bug ID: HIVE-14686 (Version: 2.1.0)
# Searching for bug ID: HIVE-14674 (Version: 2.1.0)
# Searching for bug ID: HIVE-14619 (Version: 2.1.0)
# Searching for bug ID: HIVE-14617 (Version: 2.1.0)
# Searching for bug ID: HIVE-14591 (Version: 2.1.0)
# Searching for bug ID: HIVE-14564 (Version: 2.1.0)
# Searching for bug ID: HIVE-14563 (Version: 2.1.0)
# Searching for bug ID: HIVE-14557 (Version: 2.1.0)
# Searching for bug ID: HIVE-14530 (Version: 2.1.0)
# Searching for bug ID: HIVE-14529 (Version: 2.1.0)
# Searching for bug ID: HIVE-14483 (Version: 2.1.0)
# Searching for bug ID: HIVE-14481 (Version: 2.1.0)
# Searching for bug ID: HIVE-14463 (Version: 2.1.0)
# Searching for bug ID: HIVE-14424 (Version: 2.1.0)
# Searching for bug ID: HIVE-14416 (Version: 2.1.0)
# Searching for bug ID: HIVE-14394 (Version: 2.1.0)
# Searching for bug ID: HIVE-14338 (Version: 2.1.0)
# Searching for bug ID: HIVE-14330 (Version: 2.1.0)
# Searching for bug ID: HIVE-14308 (Version: 2.1.0)
# Searching for bug ID: HIVE-14295 (Version: 2.1.0)
# Searching for bug ID: HIVE-14294 (Version: 2.1.0)
# Searching for bug ID: HIVE-14293 (Version: 2.1.0)
# Searching for bug ID: HIVE-14292 (Version: 2.1.0)
# Searching for bug ID: HIVE-14274 (Version: 2.1.0)
# Searching for bug ID: HIVE-14258 (Version: 2.1.0)
# Searching for bug ID: HIVE-14254 (Version: 2.1.0)
# Searching for bug ID: HIVE-14244 (Version: 2.1.0)
# Searching for bug ID: HIVE-14234 (Version: 2.1.0)
# Searching for bug ID: HIVE-14192 (Version: 2.1.0)
# Searching for bug ID: HIVE-14175 (Version: 2.1.0)
# Searching for bug ID: HIVE-14174 (Version: 2.1.0)
# Searching for bug ID: HIVE-14150 (Version: 2.1.0)
# Searching for bug ID: HIVE-14149 (Version: 2.1.0)
# Searching for bug ID: HIVE-14144 (Version: 2.1.0)
# Searching for bug ID: HIVE-14141 (Version: 2.1.0)
# Searching for bug ID: HIVE-14126 (Version: 2.1.0)
# Searching for bug ID: HIVE-14121 (Version: 2.1.0)
# Searching for bug ID: HIVE-14115 (Version: 2.1.0)
# Searching for bug ID: HIVE-14098 (Version: 2.1.0)
# Searching for bug ID: HIVE-14090 (Version: 2.1.0)
# Searching for bug ID: HIVE-14073 (Version: 2.1.0)
# Searching for bug ID: HIVE-14062 (Version: 2.1.0)
# Searching for bug ID: HIVE-14053 (Version: 2.1.0)
# Searching for bug ID: HIVE-14004 (Version: 2.1.0)
# Searching for bug ID: HIVE-14003 (Version: 2.1.0)
# Searching for bug ID: HIVE-13997 (Version: 2.1.0)
# Searching for bug ID: HIVE-13973 (Version: 2.1.0)
# Searching for bug ID: HIVE-13955 (Version: 2.1.0)
# Searching for bug ID: HIVE-13945 (Version: 2.1.0)
# Searching for bug ID: HIVE-13934 (Version: 2.1.0)
# Searching for bug ID: HIVE-13929 (Version: 2.1.0)
# Searching for bug ID: HIVE-13928 (Version: 2.1.0)
# Searching for bug ID: HIVE-13914 (Version: 2.1.0)
# Searching for bug ID: HIVE-13912 (Version: 2.1.0)
# Searching for bug ID: HIVE-13911 (Version: 2.1.0)
# Searching for bug ID: HIVE-13889 (Version: 2.1.0)
# Searching for bug ID: HIVE-13887 (Version: 2.1.0)
# Searching for bug ID: HIVE-13882 (Version: 2.1.0)
# Searching for bug ID: HIVE-13878 (Version: 2.1.0)
# Searching for bug ID: HIVE-13876 (Version: 2.1.0)
# Searching for bug ID: HIVE-13872 (Version: 2.1.0)
# Searching for bug ID: HIVE-13871 (Version: 2.1.0)
# Searching for bug ID: HIVE-13867 (Version: 2.1.0)
# Searching for bug ID: HIVE-13863 (Version: 2.1.0)
# Searching for bug ID: HIVE-13861 (Version: 2.1.0)
# Searching for bug ID: HIVE-13859 (Version: 2.1.0)
# Searching for bug ID: HIVE-13845 (Version: 2.1.0)
# Searching for bug ID: HIVE-13841 (Version: 2.1.0)
# Searching for bug ID: HIVE-13840 (Version: 2.1.0)
# Searching for bug ID: HIVE-13834 (Version: 2.1.0)
# Searching for bug ID: HIVE-13832 (Version: 2.1.0)
# Searching for bug ID: HIVE-13831 (Version: 2.1.0)
# Searching for bug ID: HIVE-13821 (Version: 2.1.0)
# Searching for bug ID: HIVE-13818 (Version: 2.1.0)
# Searching for bug ID: HIVE-13784 (Version: 2.1.0)
# Searching for bug ID: HIVE-13779 (Version: 2.1.0)
# Searching for bug ID: HIVE-13777 (Version: 2.1.0)
# Searching for bug ID: HIVE-13767 (Version: 2.1.0)
# Searching for bug ID: HIVE-13753 (Version: 2.1.0)
# Searching for bug ID: HIVE-13751 (Version: 2.1.0)
# Searching for bug ID: HIVE-13743 (Version: 2.1.0)
# Searching for bug ID: HIVE-13730 (Version: 2.1.0)
# Searching for bug ID: HIVE-13728 (Version: 2.1.0)
# Searching for bug ID: HIVE-13720 (Version: 2.1.0)
# Searching for bug ID: HIVE-13719 (Version: 2.1.0)
# Searching for bug ID: HIVE-13712 (Version: 2.1.0)
# Searching for bug ID: HIVE-13705 (Version: 2.1.0)
# Searching for bug ID: HIVE-13702 (Version: 2.1.0)
# Searching for bug ID: HIVE-13701 (Version: 2.1.0)
# Searching for bug ID: HIVE-13700 (Version: 2.1.0)
# Searching for bug ID: HIVE-13686 (Version: 2.1.0)
# Searching for bug ID: HIVE-13683 (Version: 2.1.0)
# Searching for bug ID: HIVE-13671 (Version: 2.1.0)
# Searching for bug ID: HIVE-13645 (Version: 2.1.0)
# Searching for bug ID: HIVE-13628 (Version: 2.1.0)
# Searching for bug ID: HIVE-13622 (Version: 2.1.0)
# Searching for bug ID: HIVE-13600 (Version: 2.1.0)
# Searching for bug ID: HIVE-13599 (Version: 2.1.0)
# Searching for bug ID: HIVE-13572 (Version: 2.1.0)
# Searching for bug ID: HIVE-13563 (Version: 2.1.0)
# Searching for bug ID: HIVE-13533 (Version: 2.1.0)
# Searching for bug ID: HIVE-13510 (Version: 2.1.0)
# Searching for bug ID: HIVE-13488 (Version: 2.1.0)
# Searching for bug ID: HIVE-13487 (Version: 2.1.0)
# Searching for bug ID: HIVE-13485 (Version: 2.1.0)
# Searching for bug ID: HIVE-13458 (Version: 2.1.0)
# Searching for bug ID: HIVE-13438 (Version: 2.1.0)
# Searching for bug ID: HIVE-13434 (Version: 2.1.0)
# Searching for bug ID: HIVE-13396 (Version: 2.1.0)
# Searching for bug ID: HIVE-13388 (Version: 2.1.0)
# Searching for bug ID: HIVE-13343 (Version: 2.1.0)
# Searching for bug ID: HIVE-13342 (Version: 2.1.0)
# Searching for bug ID: HIVE-13327 (Version: 2.1.0)
# Searching for bug ID: HIVE-13325 (Version: 2.1.0)
# Searching for bug ID: HIVE-13291 (Version: 2.1.0)
# Searching for bug ID: HIVE-13287 (Version: 2.1.0)
# Searching for bug ID: HIVE-13284 (Version: 2.1.0)
# Searching for bug ID: HIVE-13269 (Version: 2.1.0)
# Searching for bug ID: HIVE-13267 (Version: 2.1.0)
# Searching for bug ID: HIVE-13262 (Version: 2.1.0)
# Searching for bug ID: HIVE-13258 (Version: 2.1.0)
# Searching for bug ID: HIVE-13256 (Version: 2.1.0)
# Searching for bug ID: HIVE-13255 (Version: 2.1.0)
# Searching for bug ID: HIVE-13251 (Version: 2.1.0)
# Searching for bug ID: HIVE-13246 (Version: 2.1.0)
# Searching for bug ID: HIVE-13245 (Version: 2.1.0)
# Searching for bug ID: HIVE-13242 (Version: 2.1.0)
# Searching for bug ID: HIVE-13233 (Version: 2.1.0)
# Searching for bug ID: HIVE-13227 (Version: 2.1.0)
# Searching for bug ID: HIVE-13223 (Version: 2.1.0)
# Searching for bug ID: HIVE-13210 (Version: 2.1.0)
# Searching for bug ID: HIVE-13209 (Version: 2.1.0)
# Searching for bug ID: HIVE-13199 (Version: 2.1.0)
# Searching for bug ID: HIVE-13190 (Version: 2.1.0)
# Searching for bug ID: HIVE-13185 (Version: 2.1.0)
# Searching for bug ID: HIVE-13153 (Version: 2.1.0)
# Searching for bug ID: HIVE-13135 (Version: 2.1.0)
# Searching for bug ID: HIVE-13128 (Version: 2.1.0)
# Searching for bug ID: HIVE-13119 (Version: 2.1.0)
# Searching for bug ID: HIVE-13110 (Version: 2.1.0)
# Searching for bug ID: HIVE-13109 (Version: 2.1.0)
# Searching for bug ID: HIVE-13100 (Version: 2.1.0)
# Searching for bug ID: HIVE-13089 (Version: 2.1.0)
# Searching for bug ID: HIVE-13087 (Version: 2.1.0)
# Searching for bug ID: HIVE-13086 (Version: 2.1.0)
# Searching for bug ID: HIVE-13079 (Version: 2.1.0)
# Searching for bug ID: HIVE-13077 (Version: 2.1.0)
# Searching for bug ID: HIVE-13070 (Version: 2.1.0)
# Searching for bug ID: HIVE-13016 (Version: 2.1.0)
# Searching for bug ID: HIVE-13015 (Version: 2.1.0)
# Searching for bug ID: HIVE-12995 (Version: 2.1.0)
# Searching for bug ID: HIVE-12990 (Version: 2.1.0)
# Searching for bug ID: HIVE-12980 (Version: 2.1.0)
# Searching for bug ID: HIVE-12881 (Version: 2.1.0)
# Searching for bug ID: HIVE-12846 (Version: 2.1.0)
# Searching for bug ID: HIVE-12837 (Version: 2.1.0)
# Searching for bug ID: HIVE-12812 (Version: 2.1.0)
# Searching for bug ID: HIVE-12792 (Version: 2.1.0)
# Searching for bug ID: HIVE-12757 (Version: 2.1.0)
# Searching for bug ID: HIVE-12752 (Version: 2.1.0)
# Searching for bug ID: HIVE-12656 (Version: 2.1.0)
# Searching for bug ID: HIVE-12644 (Version: 2.1.0)
# Searching for bug ID: HIVE-12635 (Version: 2.1.0)
# Searching for bug ID: HIVE-12614 (Version: 2.1.0)
# Searching for bug ID: HIVE-12165 (Version: 2.1.0)
# Searching for bug ID: HIVE-7239 (Version: 2.1.0)
# Searching for bug ID: HIVE-27960 (Version: 2.3.9)
# Searching for bug ID: HIVE-27315 (Version: 3.1.2)
# Searching for bug ID: HIVE-26872 (Version: 3.1.2)
# Searching for bug ID: HIVE-26434 (Version: 2.3.9)
# Searching for bug ID: HIVE-27140 (Version: 3.1.2)
# Searching for bug ID: HIVE-26114 (Version: 3.1.2)
# Searching for bug ID: HIVE-25561 (Version: 2.3.8)
# Searching for bug ID: HIVE-24553 (Version: 2.3.8)
# Searching for bug ID: HIVE-24551 (Version: 2.3.8)
# Searching for bug ID: HIVE-24512 (Version: 2.3.8)
# Searching for bug ID: HIVE-28217 (Version: 3.1.2)
# Searching for bug ID: HIVE-27350 (Version: 3.1.2)
# Searching for bug ID: HIVE-26664 (Version: 3.1.2)
# Searching for bug ID: HIVE-26663 (Version: 3.1.2)
# Searching for bug ID: HIVE-26568 (Version: 3.1.2)
# Searching for bug ID: HIVE-26530 (Version: 3.1.2)
# Searching for bug ID: HIVE-26232 (Version: 3.1.2)
# Searching for bug ID: HIVE-25991 (Version: 3.1.2)
# Searching for bug ID: HIVE-25876 (Version: 3.1.2)
# Searching for bug ID: HIVE-25844 (Version: 3.1.2)
# Searching for bug ID: HIVE-25839 (Version: 3.1.2)
# Searching for bug ID: HIVE-25797 (Version: 3.1.2)
# Searching for bug ID: HIVE-25499 (Version: 3.1.2)
# Searching for bug ID: HIVE-25458 (Version: 3.1.2)
# Searching for bug ID: HIVE-25416 (Version: 3.1.2)
# Searching for bug ID: HIVE-25298 (Version: 3.1.2)
# Searching for bug ID: HIVE-25170 (Version: 3.1.2)
# Searching for bug ID: HIVE-25156 (Version: 3.1.2)
# Searching for bug ID: HIVE-25093 (Version: 3.1.2)
# Searching for bug ID: HIVE-25041 (Version: 3.1.2)
# Searching for bug ID: HIVE-24949 (Version: 3.1.2)
# Searching for bug ID: HIVE-24689 (Version: 3.1.2)
# Searching for bug ID: HIVE-24653 (Version: 3.1.2)
# Searching for bug ID: HIVE-24573 (Version: 3.1.2)
# Searching for bug ID: HIVE-24517 (Version: 3.1.2)
# Searching for bug ID: HIVE-24467 (Version: 2.3.4)
# Searching for bug ID: HIVE-24342 (Version: 3.1.2)
# Searching for bug ID: HIVE-24319 (Version: 3.1.2)
# Searching for bug ID: HIVE-24193 (Version: 3.1.2)
# Searching for bug ID: HIVE-24113 (Version: 3.1.2)
# Searching for bug ID: HIVE-24083 (Version: 3.1.2)
# Searching for bug ID: HIVE-23872 (Version: 3.1.2)
# Searching for bug ID: HIVE-23719 (Version: 3.1.2)
# Searching for bug ID: HIVE-23583 (Version: 3.1.2)
# Searching for bug ID: HIVE-23498 (Version: 3.1.2)
# Searching for bug ID: HIVE-23129 (Version: 3.1.2)
# Searching for bug ID: HIVE-23128 (Version: 3.1.2)
# Searching for bug ID: HIVE-23088 (Version: 3.1.2)
# Searching for bug ID: HIVE-22905 (Version: 3.1.2)
# Searching for bug ID: HIVE-22901 (Version: 3.1.2)
# Searching for bug ID: HIVE-22807 (Version: 3.1.2)
# Searching for bug ID: HIVE-22712 (Version: 3.1.2)
# Searching for bug ID: HIVE-22578 (Version: 3.1.2)
# Searching for bug ID: HIVE-22461 (Version: 3.1.2)
# Searching for bug ID: HIVE-22408 (Version: 3.1.2)
# Searching for bug ID: HIVE-22393 (Version: 3.1.2)
# Searching for bug ID: HIVE-22373 (Version: 3.1.2)
# Searching for bug ID: HIVE-22344 (Version: 3.1.2)
# Searching for bug ID: HIVE-22301 (Version: 3.1.2)
# Searching for bug ID: HIVE-22255 (Version: 3.1.2)
# Searching for bug ID: HIVE-22162 (Version: 3.1.2)
# Searching for bug ID: HIVE-21829 (Version: 3.1.2)
# Searching for bug ID: HIVE-21753 (Version: 3.1.2)
# Searching for bug ID: HIVE-21489 (Version: 2.3.4)
# Searching for bug ID: HIVE-24915 (Version: 2.3.4)
# Searching for bug ID: HIVE-24406 (Version: 2.3.4)
# Searching for bug ID: HIVE-21971 (Version: 2.3.4)
# Searching for bug ID: HIVE-21614 (Version: 2.3.4)
# Searching for bug ID: HIVE-21536 (Version: 2.3.4)
# Searching for bug ID: HIVE-21508 (Version: 2.3.4)
# Searching for bug ID: HIVE-21374 (Version: 2.3.4)
# Searching for bug ID: HIVE-21200 (Version: 2.3.4)
# Searching for bug ID: HIVE-21136 (Version: 2.3.4)
# Searching for bug ID: HIVE-16839 (Version: 2.3.4)

# %%
os.chdir(project_repo)
output_file = 'Hive_Modified_Files.csv'

try:
    with open(output_file, 'w+', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        for bug_id, data in bug_file_map.items():
            bug_id_str = str(bug_id)
            version_str = str(data['version'])
            files_str = ";".join(data['files'])
            writer.writerow([bug_id_str, version_str, files_str])
        print(f"Output has been written to {output_file}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Output has been written to Hive_Modified_Files.csv

# %% [markdown]
# ## 3. Gather Independant Variables for Each File in Each Version of Hive
#
# We will now use  *SciTools Understand* to collect a plethora of independent variables that will eventually help us predict bugs. First though, we need to retrieve the very last commit before the release of each version of the software.

# %% [markdown]
# From the [Apache Hive tags](https://github.com/apache/hive/tags), we can fetch manually the commit for each of the software version

# %%
hive_versions = {
    "2.0.0": "7f9f1fcb8697fb33f0edc2c391930a3728d247d7",
    "2.0.1": "e3cfeebcefe9a19c5055afdcbb00646908340694",
    "2.1.0": "9265bc24d75ac945bde9ce1a0999fddd8f2aae29",
    "2.1.1": "1af77bbf8356e86cabbed92cfa8cc2e1470a1d5c",
    "2.2.0": "da840b0f8fa99cab9f004810cd22abc207493cae",
    "2.3.0": "6f4c35c9e904d226451c465effdc5bfd31d395a0",
    "2.3.1": "7590572d9265e15286628013268b2ce785c6aa08",
    "2.3.2": "857a9fd8ad725a53bd95c1b2d6612f9b1155f44d",
    "2.3.3": "3f7dde31aed44b5440563d3f9d8a8887beccf0be",
    "2.3.4": "56acdd2120b9ce6790185c679223b8b5e884aaf2",
    "2.3.5": "76595628ae13b95162e77bba365fe4d2c60b3f29",
    "2.3.6": "2c2fdd524e8783f6e1f3ef15281cc2d5ed08728f",
    "2.3.7": "cb213d88304034393d68cc31a95be24f5aac62b6",
    "2.3.8": "f1e87137034e4ecbe39a859d4ef44319800016d7",
    "2.3.9": "92dd0159f440ca7863be3232f3a683a510a62b9d",
    "2.3.10": "5160d3af392248255f68e41e1e0557eae4d95273",
    "3.0.0": "ce61711a5fa54ab34fc74d86d521ecaeea6b072a",
    "3.1.0": "bcc7df95824831a8d2f1524e4048dfc23ab98c19",
    "3.1.1": "f4e0529634b6231a0072295da48af466cf2f10b7",
    "3.1.2": "8190d2be7b7165effa62bd21b7d60ef81fb0e4af",
    "3.1.3": "4df4d75bf1e16fe0af75aad0b4179c34c07fc975",
    "4.0.0": "183f8cb41d3dbed961ffd27999876468ff06690c",
    "4.0.1": "3af4517eb8cfd9407ad34ed78a0b48b57dfaa264"
}

# %% [markdown]
# These different release dates will allow us to associate a commit to specific a version of Hive

# %%
output_file = project_repo.joinpath("Hive_Last_Commits.csv")

with open(output_file, mode='w', newline='') as file:
    writer = csv.writer(file)

    writer.writerow(["Version", "Commit Hash"])

    for version, commit in hive_versions.items():
        writer.writerow([version, commit])

print("Derniers commits pour chaque version enregistrés dans 'Hive_Last_Commits.csv'")
# Out:
# Derniers commits pour chaque version enregistrés dans 'Hive_Last_Commits.csv'
